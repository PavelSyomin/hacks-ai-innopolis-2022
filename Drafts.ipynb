# %%
#!c1.32
# %pip install geojson shapely seaborn

# %%
#!c1.32
import geojson
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from shapely.geometry import shape
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.metrics import make_scorer, recall_score, precision_score
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from xgboost import XGBClassifier

# %matplotlib inline

# %% [markdown]
# # Загрузка данных

# %%
#!c1.32
df = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
df.head(3)

# %%
df.info()

# %% [markdown]
# # 0. Baseline (простой Random Forest)

# %%
X = df.drop(["id",".geo", "crop"], axis = 1)
y = df["crop"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
rfc = RandomForestClassifier(random_state=0, n_estimators = 3)
rfc.fit(X_train, y_train)

# %%
y_pred_0 = rfc.predict(X_test)
recall_score(y_test, y_pred_0, average="macro", zero_division=0)

# %%
X_test = test.drop([".geo", "id"], axis=1)
ids = test["id"].to_list()
y_pred_test_0 = rfc.predict(X_test)
submission = pd.DataFrame({"id": ids, "crop": y_pred_test_0})
submission.to_csv("submission_0.csv", index=None)

# %% [markdown]
# # 1. Разные классификаторы без работы с признаками
#
# Везде подбираются оптимальные параметры с помощью grid search.

# %%
#!c1.32
recall_scorer = make_scorer(recall_score, average="macro", zero_division=0)

# %% [markdown]
# ## 1.1. Random forest

# %%
gs_params = {
    "n_estimators": range(3, 30),
    "criterion": ["gini", "entropy"],
    "max_depth": range(3, 31, 3),
    "min_samples_split": range(5, 31, 5)
}

gs = GridSearchCV(RandomForestClassifier(), gs_params, scoring=recall_scorer, cv=3, verbose=2)
gs.fit(X_train, y_train)

# %%
gs.best_score_, gs.best_estimator_

# %%
X_test = test.drop([".geo", "id"], axis=1)
ids = test["id"].to_list()
y_pred_test_1 = gs.best_estimator_.predict(X_test)
submission1 = pd.DataFrame({"id": ids, "crop": y_pred_test_1})
submission1.to_csv("submission_1.csv", index=None)

# %% [markdown]
# ## 2. Ridge classifier

# %%
gs2_params = {
    "alpha": [x / 10 for x in range(1, 101, 2)]
}

gs2 = GridSearchCV(RidgeClassifier(), gs2_params, scoring=recall_scorer, cv=3, verbose=2)
gs2.fit(X_train, y_train)

# %%
gs2.best_score_, gs2.best_estimator_

# %% [markdown]
# ## 1.3. Logistic regression

# %%
gs3_params = {
    "penalty": ["l1", "l2", "none", "elasticnet"],
    "C": [0.01, 0.1, 0.5, 1, 10, 100]
}

gs3 = GridSearchCV(LogisticRegression(), gs3_params, scoring=recall_scorer, cv=3, verbose=2)
gs3.fit(X_train, y_train)

# %%
gs3.best_score_, gs3.best_estimator_

# %% [markdown]
# ## 1.4. SVC

# %%
gs4_params = {
    "C": [0.01, 0.1, 0.5, 1, 5, 10, 100],
    "kernel": ["linear", "poly", "rbf", "sigmoid"],
    "degree": range(1, 5),
    "decision_function_shape": ["ovr", "ovo"]    
}

gs4 = GridSearchCV(SVC(), gs4_params, scoring=recall_scorer, cv=3, verbose=2)
gs4.fit(X_train, y_train)

# %%
gs4.best_score_, gs4.best_estimator_

# %% [markdown]
# ## 1.5. GradientBoosting Classifier

# %%
gs5_params = {
    "learning_rate": [0.01, 0.1, 1, 10, 100],
    "n_estimators": range(6, 16, 3),
    "max_depth": range(3, 10, 3),
    #"min_samples_split": range(5, 31, 5)
}

gs5 = GridSearchCV(GradientBoostingClassifier(), gs5_params, scoring=recall_scorer, cv=3, verbose=2)
gs5.fit(X_train, y_train)

# %%
gs5.best_score_, gs5.best_estimator_

# %% [markdown]
# ## 1.6. CatBoost Classifier

# %%
gs6_params = {
    "learning_rate": [0.01, 0.1, 0.25, 0.5, 1],
    "depth": range(2, 10, 2),
    #"l2_leaf_reg": [1, 3, 5, 7, 9]
}

cbc = CatBoostClassifier(iterations=100, verbose=100, loss_function="MultiClass")
gs6 = GridSearchCV(cbc, gs6_params, scoring=recall_scorer, cv=3, verbose=2)
gs6.fit(X, y)

# %%
gs6.best_score_, gs6.best_estimator_

# %%
gs6_results = pd.DataFrame(gs6.cv_results_)
gs6_results.columns

# %%
gs6_results.pivot_table(index="param_depth",
                       columns="param_learning_rate",
                       values="mean_test_score",
                       aggfunc="mean").plot()

# %%
X_test = test.drop([".geo", "id"], axis=1)
ids = test["id"].to_list()
y_pred_test_6 = gs6.best_estimator_.predict(X_test)
submission6 = pd.DataFrame({"id": ids, "crop": y_pred_test_6.flatten()})
submission6.to_csv("submission_6.csv", index=None)

# %% [markdown]
# # 1.7 Catboost (v2)

# %%
gs7_params = {
    "learning_rate": [0.1, 0.25, 0.5],
    "depth": range(3, 7),
    "l2_leaf_reg": [3, 7, 11]
}

cbc = CatBoostClassifier(iterations=100, verbose=100, loss_function="MultiClass")
gs7 = GridSearchCV(cbc, gs7_params, scoring=recall_scorer, cv=3, verbose=2)
gs7.fit(X, y)

# %%
gs7.best_score_, gs7.best_estimator_

# %% [markdown]
# ## 1.8. KNN

# %%
gs18_params = {
    "n_neighbors": range(3, 10),
    "weights": ["uniform", "distance"],
    "algorithm": ["auto", "ball_tree", "kd_tree"],
    "leaf_size": [20, 30, 40, 50]
}

gs18 = GridSearchCV(KNeighborsClassifier(), gs18_params, scoring=recall_scorer, cv=3, verbose=2)
gs18.fit(X, y)

# %%
gs18.best_score_, gs18.best_estimator_

# %% [markdown]
# ## 1.9. Perceptron

# %%
gs19_params = {
    "hidden_layer_sizes": [(100,), (50,)],
    "activation": ["relu", "tahn", "logistic"],
    "alpha": [0.001, 0.01, 0.1],
    "learning_rate_init": [0.0001, 0.001, 0.01,],
   # "solver": ["lbfgs", "sgd", "adam"]
}

gs19 = GridSearchCV(MLPClassifier(max_iter=500), gs19_params, scoring=recall_scorer, cv=3, verbose=2)
gs19.fit(X, y)

# %%
gs19.best_score_, gs19.best_estimator_

# %%
ids = test["id"].to_list()
y_pred_test_19 = gs19.best_estimator_.predict(X_test)
submission19 = pd.DataFrame({"id": ids, "crop": y_pred_test_19})
submission19.to_csv("submission_19.csv", index=None)

# %% [markdown]
# ## 1.10. XGBoost

# %%
gs110_params = {
    "n_estimators": range(10, 211, 25),
    "max_depth": range(3, 8),
    "learning_rate": [0.001, 0.01, 0.1, 1],
}

gs110 = GridSearchCV(XGBClassifier(objective="multi:softmax"), gs110_params, scoring=recall_scorer, cv=3, verbose=2)
gs110.fit(X, y)

# %%
gs110.best_score_, gs110.best_estimator_

# %%
X_test = test.drop([".geo", "id"], axis=1)
ids = test["id"].to_list()
y_pred_test_110 = gs110.predict(X_test)
submission110 = pd.DataFrame({"id": ids, "crop": y_pred_test_110})
submission110.to_csv("submission_110.csv", index=None)

# %% [markdown]
# ## 1.11. LightGBM

# %%
gs111_params = {
    "num_leaves": range(10, 101, 20),
    "max_depth": range(3, 8),
    "learning_rate": [0.001, 0.01, 0.1, 0.5, 1],
}

gs111 = GridSearchCV(LGBMClassifier(), gs111_params, scoring=recall_scorer, cv=3, verbose=2)
gs111.fit(X, y)

# %%
gs111.best_score_, gs111.best_estimator_

# %%
X_test = test.drop([".geo", "id"], axis=1)
ids = test["id"].to_list()
y_pred_test_111 = gs111.predict(X_test)
submission111 = pd.DataFrame({"id": ids, "crop": y_pred_test_111})
submission111.to_csv("submission_111.csv", index=None)

# %% [markdown]
# # 2. С обработкой признаков

# %% [markdown]
# ## 2.1. Добавим широту и долготу

# %%
import geojson
from shapely.geometry import shape

# %%
df["shape"] = df[".geo"].apply(lambda x: shape(geojson.loads(x)))

# %%
df["shape"][500].length

# %%
df["shape_type"] = df["shape"].apply(lambda x: x.type)

# %%
df["shape_type"].value_counts()

# %%
df.loc[df["shape_type"] == "MultiPolygon", "shape"].iloc[0].area

# %%
df["lon"] = df["shape"].apply(lambda x: x.representative_point().coords[0][0])
df["lat"] = df["shape"].apply(lambda x: x.representative_point().coords[0][1])

# %%
df["lon"].hist(bins=int(df["lon"].max() - df["lon"].min()))

# %%
df["lat"].hist(bins=int(df["lat"].max() - df["lat"].min()))

# %%
X = df.drop(["id",".geo", "crop", "shape", "shape_type"], axis=1)
y = df["crop"]

# %% [markdown]
# ### 2.1.1 CatBoost

# %%
gs21_params = {
    "learning_rate": [0.1, 0.25, 0.5],
    "depth": range(3, 7)
}

cbc = CatBoostClassifier(iterations=100, verbose=100, loss_function="MultiClass")
gs21 = GridSearchCV(cbc, gs21_params, scoring=recall_scorer, cv=3, verbose=2)
gs21.fit(X, y)

# %%
gs21.best_score_, gs21.best_estimator_

# %%
test["shape"] = test[".geo"].apply(lambda x: shapely.geometry.shape(geojson.loads(x)))
test["lon"] = test["shape"].apply(lambda x: x.representative_point().coords[0][0])
test["lat"] = test["shape"].apply(lambda x: x.representative_point().coords[0][1])
X_test = test.drop([".geo", "id", "shape"], axis=1)

# %%
ids = test["id"].to_list()
y_pred_test_21 = gs21.best_estimator_.predict(X_test)
submission21 = pd.DataFrame({"id": ids, "crop": y_pred_test_21.flatten()})
submission21.to_csv("submission_21.csv", index=None)

# %% [markdown]
# ### 2.1.2 RandomForest

# %%
gs212_params = {
    "n_estimators": range(10, 60, 2),
    "max_depth": range(3, 16, 3),
    "min_samples_split": range(15, 41, 5)
}

gs212 = GridSearchCV(RandomForestClassifier(criterion="entropy"), gs212_params, scoring=recall_scorer, cv=3, verbose=2, n_jobs=3)
gs212.fit(X_train, y_train)

# %%
gs212.best_score_, gs212.best_estimator_

# %%
y_pred_test_212 = gs21.best_estimator_.predict(X_test)
submission212 = pd.DataFrame({"id": ids, "crop": y_pred_test_212.flatten()})
submission212.to_csv("submission_212.csv", index=None)

# %% [markdown]
# ### 2.1.3. XGBoost

# %%
gs213_params = {
    "n_estimators": range(50, 151, 25),
    "max_depth": range(3, 6),
    "learning_rate": [0.01, 0.05, 0.1, 0.5],
}

gs213 = GridSearchCV(XGBClassifier(objective="multi:softmax"), gs213_params, scoring=recall_scorer, cv=3, verbose=2)
gs213.fit(X, y)

# %%
gs213.best_score_, gs213.best_estimator_

# %%
y_pred_test_213 = gs213.best_estimator_.predict(X_test)
submission213 = pd.DataFrame({"id": ids, "crop": y_pred_test_213})
submission213.to_csv("submission_213.csv", index=None)

# %% [markdown]
# ## 2.2. Добавим количество углов у контура поля

# %%
def count_edges(shape):
    shape_type = shape.type
    if shape_type == "Polygon":
        n_edges = len(shape.exterior.coords)
    elif shape_type == "MultiPolygon":
        n_edges = sum([len(contour.exterior.coords) for contour in shape.geoms])
    elif shape_type == "GeometryCollection":
        n_edges = 0
        for element in shape.geoms:
            if element.type == "Polygon":
                n_edges += len(element.exterior.coords)
    else:
        n_edges = np.nan                
        
    return n_edges

# %%
df["edges"] = df["shape"].apply(count_edges)

# %%
df.groupby("shape_type")["edges"].mean()

# %%
df["edges"].hist()

# %%
X = df.drop(["id",".geo", "crop", "shape", "shape_type"], axis=1)
y = df["crop"]

# %% [markdown]
# ### 2.2.1. CatBoost

# %%
gs221_params = {
    "learning_rate": [0.1, 0.2, 0.25, 0.3, 0.5],
    "depth": range(3, 7)
}

cbc = CatBoostClassifier(iterations=100, verbose=100, loss_function="MultiClass")
gs221 = GridSearchCV(cbc, gs221_params, scoring=recall_scorer, cv=3, verbose=2)
gs221.fit(X, y)

# %%
gs221.best_score_, gs221.best_estimator_

# %%
gs221.best_estimator_.get_params()

# %%
gs221.best_estimator_.get_feature_importance()

# %%
test["shape"] = test[".geo"].apply(lambda x: shapely.geometry.shape(geojson.loads(x)))
test["edges"] = test["shape"].apply(count_edges)
test["lon"] = test["shape"].apply(lambda x: x.representative_point().coords[0][0])
test["lat"] = test["shape"].apply(lambda x: x.representative_point().coords[0][1])
X_test = test.drop([".geo", "id", "shape"], axis=1)

# %%
ids = test["id"].to_list()
y_pred_test_221 = gs221.best_estimator_.predict(X_test)
submission221 = pd.DataFrame({"id": ids, "crop": y_pred_test_221.flatten()})
submission221.to_csv("submission_221.csv", index=None)

# %% [markdown]
# ### 2.2.2. XGBoost

# %%
gs222_params = {
    "n_estimators": range(50, 151, 50),
    "max_depth": range(3, 6),
    "learning_rate": [x / 10 for x in range(1, 6, 2)],
    #"gamma": [0, 1],
}

gs222 = GridSearchCV(XGBClassifier(booster="dart", objective="multi:softmax", nthread=4), gs222_params, scoring=recall_scorer, cv=3, verbose=2)
gs222.fit(X, y)

# %%
gs222.best_score_, gs222.best_estimator_

# %%
test["shape"] = test[".geo"].apply(lambda x: shapely.geometry.shape(geojson.loads(x)))
test["lon"] = test["shape"].apply(lambda x: x.representative_point().coords[0][0])
test["lat"] = test["shape"].apply(lambda x: x.representative_point().coords[0][1])
test["edges"] = test["shape"].apply(count_edges)
X_test = test.drop([".geo", "id", "shape"], axis=1)

# %%
ids = test["id"].to_list()
y_pred_test_222 = gs222.best_estimator_.predict(X_test)
submission222 = pd.DataFrame({"id": ids, "crop": y_pred_test_222})
submission222.to_csv("submission_222_2.csv", index=None)

# %% [markdown]
# ### 2.2.3. LightGBM

# %%
gs223_params = {
    "num_leaves": range(10, 101, 20),
    "max_depth": range(3, 8),
    "learning_rate": [0.001, 0.01, 0.1, 0.5, 1],
}

gs223 = GridSearchCV(LGBMClassifier(), gs223_params, scoring=recall_scorer, cv=3, verbose=2)
gs223.fit(X, y)

# %%
gs223.best_score_, gs223.best_estimator_

# %%
test["shape"] = test[".geo"].apply(lambda x: shapely.geometry.shape(geojson.loads(x)))
test["edges"] = test["shape"].apply(count_edges)
test["lon"] = test["shape"].apply(lambda x: x.representative_point().coords[0][0])
test["lat"] = test["shape"].apply(lambda x: x.representative_point().coords[0][1])
X_test = test.drop([".geo", "id", "shape"], axis=1)

# %%
ids = test["id"].to_list()
y_pred_test_223 = gs223.best_estimator_.predict(X_test)
submission223 = pd.DataFrame({"id": ids, "crop": y_pred_test_223})
submission223.to_csv("submission_223.csv", index=None)

# %% [markdown]
# ## 2.3. Заполняем нули средним значением соседей

# %%
arr = df.iloc[:, 2:-6].drop(columns=".geo").to_numpy()
arr_left = np.roll(arr, 1, axis=1)
arr_left[:, 0] = 0
arr_right = np.roll(arr, -1, axis=1)
arr_right[:, -1] = 0
arr_avg = (arr_left + arr_right) / 2
arr_filled = np.where(arr == 0, arr_avg, arr)

# %%
pd.DataFrame(arr_filled)

# %%
df_filled = pd.concat([df["area"], pd.DataFrame(arr_filled), df[["crop", "shape"]]], axis=1)
df_filled.columns = df.drop(columns=["id", ".geo"]).columns[:-4]

# %%
df_filled["edges"] = df_filled["shape"].apply(count_edges)
df_filled["lon"] = df_filled["shape"].apply(lambda x: x.representative_point().coords[0][0])
df_filled["lat"] = df_filled["shape"].apply(lambda x: x.representative_point().coords[0][1])

# %%
df_filled.info()

# %%
X = df_filled.drop(columns=["crop", "shape"])
y = df_filled["crop"]

# %%
gs231_params = {
    "learning_rate": [0.1, 0.2, 0.25, 0.3, 0.5],
    "depth": range(3, 7),
    "l2_leaf_reg": [0.1, 1, 10, 100]
}

cbc = CatBoostClassifier(iterations=100, verbose=100, loss_function="MultiClass")
gs231 = GridSearchCV(cbc, gs231_params, scoring=recall_scorer, cv=3, verbose=2)
gs231.fit(X, y)

# %%
gs231.best_score_, gs231.best_estimator_

# %%
y_pred_test_231 = gs231.best_estimator_.predict(X_test)
submission231 = pd.DataFrame({"id": ids, "crop": y_pred_test_231.flatten()})
submission231.to_csv("submission_231.csv", index=None)

# %% [markdown]
# ## 2.4. Линейная интерполяция нулей
#
# В отличие от п. 2.3, здесь всё делается по-умному:
#  - с учётом того, что колонки идут в абы каком порядке, а не хронологически;
#  - с учётом того, что значения идут не через равные интервалы;
#  - с учётом того, что пропусков может быть несколько подряд.

# %%
class LinearTSImputer(BaseEstimator, TransformerMixin):
    def __init__(self, col_prefix="nd_mean_"):
        self.col_prefix = col_prefix        
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        self._series = []
        X_processed = X.loc[:, X.columns.str.contains(self.col_prefix)]
        X_rest = X.loc[:, ~X.columns.str.contains(self.col_prefix)]
        
        for _, row in X_processed.iterrows():
            row[row == 0] = np.nan
            index = pd.to_datetime(row.index.str.replace(self.col_prefix, ""))
            row = row.set_axis(index)
            row = row.interpolate(method="time", limit_direction="both").sort_index()
            self._series.append(row)
        
        result = pd.DataFrame(self._series)
        result.rename(columns=lambda x: self.col_prefix + x.strftime("%Y-%m-%d"), inplace=True)
        
        result = pd.concat([result, X_rest], axis=1)
        
        return result

# %%
gs241_params = {
    "learning_rate": [0.01, 0.1, 0.25, 0.5, 1],
    "depth": range(2, 10, 2),
    #"l2_leaf_reg": [1, 3, 5, 7, 9]
}

cbc = CatBoostClassifier(iterations=100, verbose=100, loss_function="MultiClass")
gs241 = GridSearchCV(cbc, gs241_params, scoring=recall_scorer, cv=3, verbose=2)
gs241.fit(LinearTSImputer().fit_transform(X), y)

# %%
gs241.best_score_, gs241.best_estimator_

# %%
gs242_params = {
    "n_estimators": range(60, 151, 25),
    "max_depth": range(3, 5),
    "learning_rate": [0.01, 0.1, 1],
}

gs242 = GridSearchCV(XGBClassifier(objective="multi:softmax"), gs242_params, scoring=recall_scorer, cv=3, verbose=2, error_score="raise")
gs242.fit(LinearTSImputer().fit_transform(X), y)

# %%
gs242.best_score_, gs242.best_estimator_

# %%
X_test = test.drop([".geo", "id"], axis=1)
X_test = LinearTSImputer().fit_transform(X_test)
ids = test["id"].to_list()
y_pred_test_242 = gs242.best_estimator_.predict(X_test)
submission242 = pd.DataFrame({"id": ids, "crop": y_pred_test_242})
submission242.to_csv("submission_242.csv", index=None)

# %%
def count_edges(shape):
    shape_type = shape.type
    if shape_type == "Polygon":
        n_edges = len(shape.exterior.coords)
    elif shape_type == "MultiPolygon":
        n_edges = sum([len(contour.exterior.coords) for contour in shape.geoms])
    elif shape_type == "GeometryCollection":
        n_edges = 0
        for element in shape.geoms:
            if element.type == "Polygon":
                n_edges += len(element.exterior.coords)
    else:
        n_edges = np.nan                
        
    return n_edges

class GeoTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, length=False, derived=False, computed_area=False):
        self.length = length
        self.derived = derived
        self.computed_area = computed_area
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        result = X.copy()
        result["shape"] = result[".geo"].apply(lambda x: shape(geojson.loads(x)))
        result["edges"] = result["shape"].apply(count_edges)
        result["lon"] = result["shape"].apply(lambda x: x.representative_point().coords[0][0])
        result["lat"] = result["shape"].apply(lambda x: x.representative_point().coords[0][1])
        
        if self.length:
            result["length"] = result["shape"].apply(lambda x: x.length)
        if self.derived:
            result["edges_per_length"] = result["edges"] / result["length"]
            result["area_per_length"] = result["area"] / result["length"]
            result["area_per_edge"] = result["area"] / result["edges"]
        if self.computed_area:
            result["computed_area"] = result["shape"].apply(lambda x: x.area)
            
        result.drop(columns=["shape", ".geo"], inplace=True)
        
        return result

# %%
transformer_pipe = Pipeline([
    ("geo", GeoTransformer()),
    ("impute", LinearTSImputer())
])

# %%
GeoTransformer(length=True, derived=True, computed_area=True).transform(df)

# %%
res1 = transformer_pipe.fit_transform(df)
res2 = transformer_pipe.fit_transform(X)

# %%
gs252_params = {
    "n_estimators": range(60, 151, 25),
    "max_depth": range(3, 5),
    "learning_rate": [0.01, 0.1, 1],
}

gs252 = GridSearchCV(XGBClassifier(objective="multi:softmax"), gs252_params, scoring=recall_scorer, cv=3, verbose=2, error_score="raise")
gs252.fit(transformer_pipe.fit_transform(X), y)

# %%
gs252.best_score_, gs252.best_estimator_

# %%
X_test = test.drop(["id"], axis=1)
X_test = transformer_pipe.fit_transform(X_test)
ids = test["id"].to_list()
y_pred_test_252 = gs252.best_estimator_.predict(X_test)
submission252 = pd.DataFrame({"id": ids, "crop": y_pred_test_252})
submission252.to_csv("submission_252.csv", index=None)

# %%
class DescStatFeatureGenerator(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        result = X.copy()
        result["nd_mean"] = result.loc[:, result.columns.str.contains("nd")].mean(axis=1)
        result["nd_min"] = result.loc[:, result.columns.str.contains("nd")].min(axis=1)
        result["nd_max"] = result.loc[:, result.columns.str.contains("nd")].max(axis=1)
        result["nd_std"] = result.loc[:, result.columns.str.contains("nd")].std(axis=1)
        result["nd_sum"] = result.loc[:, result.columns.str.contains("nd")].sum(axis=1)
        for q in range(1, 20):
            colname = f"nd_q{q}"
            result[colname] = result.loc[:, result.columns.str.contains("nd")].quantile(q / 20, axis=1)
        
        return result

# %%
transformer_pipe_with_features = Pipeline([
    ("geo", GeoTransformer()),
    ("stats", DescStatFeatureGenerator()),
    ("impute", LinearTSImputer())
])

# %%
transformer_pipe_with_features.transform(X)

# %%
gs262_params = {
    "n_estimators": range(60, 151, 25),
    "max_depth": range(3, 5),
    "learning_rate": [0.01, 0.1, 1],
}

gs262 = GridSearchCV(XGBClassifier(objective="multi:softmax"), gs262_params, scoring=recall_scorer, cv=3, verbose=2, error_score="raise")
gs262.fit(transformer_pipe_with_features.fit_transform(X), y)

# %%
gs262.best_score_, gs262.best_estimator_

# %%
from sklearn.feature_selection import RFECV

gs262_rfecv = RFECV(gs262.best_estimator_, cv=3, scoring=recall_scorer, verbose=2)
gs262_rfecv.fit(transformer_pipe_with_features.fit_transform(X), y)

# %%
gs262.feature_names_in_

# %%
gs262_rfecv.support_

# %%
gs262_rfecv.n_features_

# %%
transformer_pipe_without_imputing = Pipeline([
    ("geo", GeoTransformer()),
    ("stats", DescStatFeatureGenerator()),
])

# %%
gs272_params = {
    "n_estimators": range(60, 151, 25),
    "max_depth": range(3, 5),
    "learning_rate": [0.01, 0.1, 1],
}

gs272 = GridSearchCV(XGBClassifier(objective="multi:softmax"), gs272_params, scoring=recall_scorer, cv=3, verbose=2, error_score="raise")
gs272.fit(transformer_pipe_without_imputing.fit_transform(X), y)

# %%
gs272.best_score_, gs272.best_estimator_

# %%
gs272_params = {
    "n_estimators": range(60, 151, 25),
    "max_depth": [4],
    "learning_rate": [0.1],
}

gs272 = GridSearchCV(XGBClassifier(objective="multi:softmax"), gs272_params, scoring=recall_scorer, cv=3, verbose=2, error_score="raise")
gs272.fit(transformer_pipe_without_imputing.fit_transform(X), y)

# %%
gs272.best_score_, gs272.best_estimator_

# %%
X_test = test.drop(["id"], axis=1)
X_test = transformer_pipe_without_imputing.fit_transform(X_test)
ids = test["id"].to_list()
y_pred_test_272 = gs272.best_estimator_.predict(X_test)
submission272 = pd.DataFrame({"id": ids, "crop": y_pred_test_272})
submission272.to_csv("submission_272.csv", index=None)

# %%
st = pd.DataFrame({"242": y_pred_test_242, "252": y_pred_test_252, "272": y_pred_test_272})

# %%
st.head(50)

# %%
st_preds = st.mode(axis=1)[0]

# %%
st_preds

# %%
submission_st = pd.DataFrame({"id": ids, "crop": st_preds})
submission_st.to_csv("submission_st.csv", index=None)

# %%
gs272_rfecv = RFECV(gs272.best_estimator_, cv=3, min_features_to_select=20, step=2, scoring=recall_scorer, verbose=2)
gs272_rfecv.fit(transformer_pipe_without_imputing.fit_transform(X), y)

# %%
gs272_rfecv.n_features_

# %%
gs272_rfecv.cv_results_

# %%
df.iloc[14, df.columns.str.contains("nd")].sort_index().plot()

# %%
res.iloc[14, res.columns.str.contains("nd")].sort_index().plot()

# %%
res.iloc[14, res.columns.str.contains("nd")].sort_index()

# %%
class LinearTSSummator(BaseEstimator, TransformerMixin):
    def __init__(self, col_prefix="nd_mean_"):
        self.col_prefix = col_prefix        
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        result = X.copy()
        result["missing_count"] = result.loc[:, result.columns.str.contains(self.col_prefix)].apply(lambda x: len(x[x == 0]), axis=1)
        
        return result

# %%
transform_pipe_with_sums = Pipeline([
    ("geo", GeoTransformer()),
    ("stats", DescStatFeatureGenerator()),
    ("cnt_missing", LinearTSSummator())
])

# %%
X = df.drop(["id", "crop"], axis=1)
y = df["crop"]

# %%
gs281_params = {
    "learning_rate": [0.01, 0.1, 0.25, 0.5, 1],
    "depth": range(2, 10, 2),
    #"l2_leaf_reg": [1, 3, 5, 7, 9]
}

cbc = CatBoostClassifier(iterations=200, verbose=100, loss_function="MultiClass")
gs281 = GridSearchCV(cbc, gs281_params, scoring=recall_scorer, cv=3, verbose=2)
gs281.fit(transform_pipe_with_sums.fit_transform(X), y)

# %%
gs281.best_score_, gs281.best_estimator_

# %%
X_test = test.drop(["id"], axis=1)
X_test = transform_pipe_with_sums.fit_transform(X_test)
ids = test["id"].to_list()
y_pred_test_281 = gs281.best_estimator_.predict(X_test)
submission281 = pd.DataFrame({"id": ids, "crop": y_pred_test_281.flatten()})
submission281.to_csv("submission_281_2.csv", index=None)

# %%
gs282_params = {
    "n_estimators": range(50, 201, 25),
    "max_depth": [3, 4, 5, 6],
    "learning_rate": [0.1, 0.2, 0.3],
}

gs282 = GridSearchCV(XGBClassifier(objective="multi:softmax"), gs282_params, scoring=recall_scorer, cv=3, verbose=2, error_score="raise")
gs282.fit(transform_pipe_with_sums.fit_transform(X), y)

# %%
gs282.best_score_, gs282.best_estimator_

# %%
X_test = test.drop(["id"], axis=1)
X_test = transform_pipe_with_sums.fit_transform(X_test)
ids = test["id"].to_list()
y_pred_test_282 = gs282.best_estimator_.predict(X_test)
submission282 = pd.DataFrame({"id": ids, "crop": y_pred_test_282})
submission282.to_csv("submission_282_2.csv", index=None)

# %%
gs283_params = {
    "num_leaves": range(10, 31, 10),
    "max_depth": range(4, 8),
    "learning_rate": [0.001, 0.01, 0.1, 1],
    "reg_lambda": [0, 1]
}

gs283 = GridSearchCV(LGBMClassifier(boosting_type="dart", n_estimators=200), gs283_params, scoring=recall_scorer, cv=3, verbose=2)
gs283.fit(transform_pipe_with_sums.fit_transform(X), y)

# %%
gs283.best_score_, gs283.best_estimator_

# %%
X_test = test.drop(["id"], axis=1)
X_test = transform_pipe_with_sums.fit_transform(X_test)
ids = test["id"].to_list()
y_pred_test_283 = gs283.best_estimator_.predict(X_test)
submission283 = pd.DataFrame({"id": ids, "crop": y_pred_test_283})
submission283.to_csv("submission_283_2.csv", index=None)

# %%
gs284_params = {
    "alpha": [0.001, 0.01, 0.1],
    "learning_rate_init": [0.0001, 0.001, 0.01, 0.1, 1],
}

gs284 = GridSearchCV(MLPClassifier(max_iter=10000, batch_size=50), gs284_params, scoring=recall_scorer, cv=3, verbose=2)
gs284.fit(transform_pipe_with_sums.fit_transform(X), y)

# %%
gs284.best_score_, gs284.best_estimator_

# %%
X_test = test.drop(["id"], axis=1)
X_test = transform_pipe_with_sums.fit_transform(X_test)
ids = test["id"].to_list()
y_pred_test_284 = gs284.best_estimator_.predict(X_test)
submission284 = pd.DataFrame({"id": ids, "crop": y_pred_test_284})
submission284.to_csv("submission_284.csv", index=None)

# %%
transform_pipe_full = Pipeline([
    ("geo", GeoTransformer()),
    ("stats", DescStatFeatureGenerator()),
    ("cnt_missing", LinearTSSummator()),
    ("impute", LinearTSImputer())
])

# %%
X = df.drop(["id", "crop"], axis=1)
y = df["crop"]

# %%
gs291_params = {
    "learning_rate": [0.01, 0.1, 0.25, 0.5, 1],
    "depth": range(2, 10, 2),
    #"l2_leaf_reg": [1, 3, 5, 7, 9]
}

cbc = CatBoostClassifier(iterations=200, verbose=100, loss_function="MultiClass")
gs291 = GridSearchCV(cbc, gs291_params, scoring=recall_scorer, cv=3, verbose=2)
gs291.fit(transform_pipe_full.fit_transform(X), y)

# %%
gs291.best_score_, gs291.best_estimator_

# %%
X_test = test.drop(["id"], axis=1)
X_test = transform_pipe_full.fit_transform(X_test)
ids = test["id"].to_list()
y_pred_test_291 = gs291.best_estimator_.predict(X_test)
submission291 = pd.DataFrame({"id": ids, "crop": y_pred_test_291.flatten()})
submission291.to_csv("submission_291.csv", index=None)

# %%
gs292_params = {
    "num_leaves": range(10, 31, 10),
    "max_depth": range(4, 8),
    "learning_rate": [0.001, 0.01, 0.1, 1],
    "reg_lambda": [0, 1]
}

gs292 = GridSearchCV(LGBMClassifier(boosting_type="dart", n_estimators=200), gs292_params, scoring=recall_scorer, cv=3, verbose=2)
gs292.fit(transform_pipe_full.fit_transform(X), y)

# %%
gs292.best_score_, gs292.best_estimator_

# %%
transform_pipe_full.fit_transform(X)

# %%
class NDVIMeanImputer(BaseEstimator, TransformerMixin):
    def __init__(self, col_prefix="nd_mean_"):
        self.col_prefix = col_prefix        
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        result = X.copy()
        cols = result.columns[result.columns.str.contains(self.col_prefix)].to_list()
        result["means"] = result.loc[:, cols].mean(axis=1)        
        cols.append("means")
        result = result.loc[:, cols].replace(0, np.nan)
        result.fillna(method="backfill", axis=1, inplace=True)
        result.drop(columns="means", inplace=True)
        
        return result

# %%
transform_pipe_na_means = Pipeline([
    ("geo", GeoTransformer()),
    ("stats", DescStatFeatureGenerator()),
    ("cnt_missing", LinearTSSummator()),
    ("impute", NDVIMeanImputer())
])

# %%
X = df.drop(["id", "crop"], axis=1)
y = df["crop"]

# %%
gs2101_params = {
    "learning_rate": [0.01, 0.1, 0.25, 0.5, 1],
    "depth": range(2, 10, 2),
    #"l2_leaf_reg": [1, 3, 5, 7, 9]
}

cbc = CatBoostClassifier(iterations=200, verbose=100, loss_function="MultiClass")
gs2101 = GridSearchCV(cbc, gs2101_params, scoring=recall_scorer, cv=3, verbose=2)
gs2101.fit(transform_pipe_na_means.fit_transform(X), y)

# %%
gs2101.best_score_, gs2101.best_estimator_

# %%
transform_pipe_adv_geo = Pipeline([
    ("geo", GeoTransformer(length=True, derived=True, computed_area=True)),
    ("stats", DescStatFeatureGenerator()),
    ("cnt_missing", LinearTSSummator())    
])

# %%
X = df.drop(["id", "crop"], axis=1)
y = df["crop"]

# %%
gs2111_params = {
    "learning_rate": [0.01, 0.1, 0.25, 0.5, 1],
    "depth": range(2, 10, 2),
    #"l2_leaf_reg": [1, 3, 5, 7, 9]
}

cbc = CatBoostClassifier(iterations=200, verbose=100, loss_function="MultiClass")
gs2111 = GridSearchCV(cbc, gs2111_params, scoring=recall_scorer, cv=3, verbose=2)
gs2111.fit(transform_pipe_adv_geo.fit_transform(X), y)

# %%
gs2111.best_score_, gs2111.best_estimator_

# %%
X_test = test.drop(["id"], axis=1)
X_test = transform_pipe_adv_geo.fit_transform(X_test)
ids = test["id"].to_list()
y_pred_test_2111 = gs2111.best_estimator_.predict(X_test)
submission2111 = pd.DataFrame({"id": ids, "crop": y_pred_test_2111.flatten()})
submission2111.to_csv("submission_2111.csv", index=None)

# %%
gs2112_params = {
    "num_leaves": range(10, 31, 10),
    "max_depth": range(4, 8),
    "learning_rate": [0.001, 0.01, 0.1, 1],
    "reg_lambda": [0, 1]    
}

gs2112 = GridSearchCV(LGBMClassifier(boosting_type="dart", n_estimators=200), gs2112_params, scoring=recall_scorer, cv=3, verbose=2)
gs2112.fit(transform_pipe_adv_geo.fit_transform(X), y)

# %%
gs2112.best_score_, gs2112.best_estimator_

# %%
X_test = test.drop(["id"], axis=1)
X_test = transform_pipe_adv_geo.fit_transform(X_test)
ids = test["id"].to_list()
y_pred_test_2112 = gs2112.best_estimator_.predict(X_test)
submission2112 = pd.DataFrame({"id": ids, "crop": y_pred_test_2112})
submission2112.to_csv("submission_2112.csv", index=None)

# %%
def draw_hist(x):
    vals = x.to_numpy().flatten()
    plot = plt.hist(vals[vals < 1], bins=10)
    return plot

# %%
plots = df.iloc[:, 2:].drop(columns=".geo").groupby("crop").apply(draw_hist)

# %%
plots[0]

# %% [markdown]
# # 3. Решения, близкие к финальным
#
# Оптимально:
#  - не заполнять нули;
#  - посчитать количество нулей (по сути некорректных значений) и вынести в отдельную колонку;
#  - извлечь долготу, широту, количество углов, длину;
#  - посчитать некоторые описательные статистики.

# %%
#!c1.32
def count_edges(shape):
    shape_type = shape.type
    if shape_type == "Polygon":
        n_edges = len(shape.exterior.coords)
    elif shape_type == "MultiPolygon":
        n_edges = sum([len(contour.exterior.coords) for contour in shape.geoms])
    elif shape_type == "GeometryCollection":
        n_edges = 0
        for element in shape.geoms:
            if element.type == "Polygon":
                n_edges += len(element.exterior.coords)
    else:
        n_edges = np.nan                
        
    return n_edges

class GeoTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, edges=False, length=False, derived=False, computed_area=False):
        self.edges = edges
        self.length = length
        self.derived = derived
        self.computed_area = computed_area
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        result = X.copy()
        result["shape"] = result[".geo"].apply(lambda x: shape(geojson.loads(x)))
        result["lon"] = result["shape"].apply(lambda x: x.representative_point().coords[0][0])
        result["lat"] = result["shape"].apply(lambda x: x.representative_point().coords[0][1])
        
        if self.edges:
            result["edges"] = result["shape"].apply(count_edges)
        if self.length:
            result["length"] = result["shape"].apply(lambda x: x.length)
        if self.derived:
            result["edges_per_length"] = result["edges"] / result["length"]
            result["area_per_length"] = result["area"] / result["length"]
            result["area_per_edge"] = result["area"] / result["edges"]
        if self.computed_area:
            result["computed_area"] = result["shape"].apply(lambda x: x.area)
            
        result.drop(columns=["shape", ".geo"], inplace=True)
        
        return result

# %%
#!c1.32
class DescStatFeatureGenerator(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        result = X.copy()
        result["nd_mean"] = result.loc[:, result.columns.str.contains("nd")].mean(axis=1)
        result["nd_min"] = result.loc[:, result.columns.str.contains("nd")].min(axis=1)
        result["nd_max"] = result.loc[:, result.columns.str.contains("nd")].max(axis=1)
        result["nd_std"] = result.loc[:, result.columns.str.contains("nd")].std(axis=1)
        result["nd_sum"] = result.loc[:, result.columns.str.contains("nd")].sum(axis=1)
        for q in range(1, 20):
            colname = f"nd_q{q}"
            result[colname] = result.loc[:, result.columns.str.contains("nd")].quantile(q / 20, axis=1)
        
        return result

# %%
#!c1.32
class MissingTSSummator(BaseEstimator, TransformerMixin):
    def __init__(self, col_prefix="nd_mean_"):
        self.col_prefix = col_prefix        
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        result = X.copy()
        result["missing_count"] = result.loc[:, result.columns.str.contains(self.col_prefix)].apply(lambda x: len(x[x == 0]), axis=1)
        
        return result

# %%
#!c1.32
transformer = Pipeline([
    ("geo", GeoTransformer(length=True)),
    ("count_missing", MissingTSSummator()),
    ("stats", DescStatFeatureGenerator())
])

# %%
#!c1.32
X = df.drop(columns=["id", "crop"])
y = df["crop"]

# %%
#!c1.32
gs31_params = {
    "learning_rate": [0.01, 0.05, 0.1, 0.2, 0.3, 0.5, 1],
    "depth": range(4, 8, 1),
    #"l2_leaf_reg": [],
    "grow_policy": ["SymmetricTree", "Depthwise", "Lossguide"],
    #"min_data_in_leaf": range(5, 50, 10)
}

cbc = CatBoostClassifier(iterations=200, verbose=False, loss_function="MultiClass",
                         random_seed=42)
gs31 = GridSearchCV(cbc, gs31_params, scoring=recall_scorer,
                    cv=3, n_jobs=32, verbose=1, error_score="raise")
gs31.fit(transformer.fit_transform(X), y)
# Out:
# Fitting 3 folds for each of 84 candidates, totalling 252 fits
# [Parallel(n_jobs=32)]: Using backend LokyBackend with 32 concurrent workers.
# /usr/local/lib/python3.8/dist-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=32)]: Done 136 tasks      | elapsed:  3.8min
# /usr/local/lib/python3.8/dist-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=32)]: Done 252 out of 252 | elapsed:  9.3min finished
# GridSearchCV(cv=3, error_score='raise',
#              estimator=<catboost.core.CatBoostClassifier object at 0x7f12db5805e0>,
#              iid='deprecated', n_jobs=32,
#              param_grid={'depth': range(4, 8),
#                          'grow_policy': ['SymmetricTree', 'Depthwise',
#                                          'Lossguide'],
#                          'learning_rate': [0.01, 0.05, 0.1, 0.2, 0.3, 0.5, 1]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=make_scorer(recall_score, average=macro, zero_division=0),
#              verbose=1)

# %%
#!c1.32
gs31.best_score_, gs31.best_estimator_.get_all_params()
# Out:
# (0.9669035099719944,
#  {'nan_mode': 'Min',
#   'eval_metric': 'MultiClass',
#   'iterations': 200,
#   'sampling_frequency': 'PerTree',
#   'leaf_estimation_method': 'Newton',
#   'grow_policy': 'Lossguide',
#   'penalties_coefficient': 1,
#   'boosting_type': 'Plain',
#   'model_shrink_mode': 'Constant',
#   'feature_border_type': 'GreedyLogSum',
#   'bayesian_matrix_reg': 0.10000000149011612,
#   'l2_leaf_reg': 3,
#   'random_strength': 1,
#   'rsm': 1,
#   'boost_from_average': False,
#   'model_size_reg': 0.5,
#   'use_best_model': False,
#   'class_names': [0, 1, 2, 3, 4, 5, 6],
#   'random_seed': 42,
#   'depth': 5,
#   'border_count': 254,
#   'bagging_temperature': 1,
#   'classes_count': 0,
#   'auto_class_weights': 'None',
#   'sparse_features_conflict_fraction': 0,
#   'leaf_estimation_backtracking': 'AnyImprovement',
#   'best_model_min_trees': 1,
#   'model_shrink_rate': 0,
#   'min_data_in_leaf': 1,
#   'loss_function': 'MultiClass',
#   'learning_rate': 0.20000000298023224,
#   'score_function': 'Cosine',
#   'task_type': 'CPU',
#   'leaf_estimation_iterations': 1,
#   'bootstrap_type': 'Bayesian',
#   'max_leaves': 31})

# %%
#!c1.32
CatBoostClassifier(iterations=200, depth=5, verbose=False,
                   loss_function="MultiClass", random_seed=42)

# %%
#!c1.32
gs32_params = {
    "booster": ["gbtree", "gblinear", "dart"],
    #"n_estimators": range(50, 201, 25),
    "max_depth": range(3, 11),
    "learning_rate": [0.001, 0.01, 0.05, 0.1, 0.2, 0.3, 0.5, 0.75, 1],
    "gamma": [0, 1, 5, 10, 100],
    "grow_policy": ["depthwise", "lossguide"]
}

gs32 = GridSearchCV(XGBClassifier(objective="multi:softmax", n_estimators=100), gs32_params,
                    scoring=recall_scorer, cv=3, verbose=2, error_score="raise",
                    n_jobs=32)
gs32.fit(transformer.fit_transform(X), y)
# Out:
# ster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.05, max_depth=10, total=   3.8s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.2, max_depth=4
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.2, max_depth=4, total=   3.8s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.3, max_depth=6
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.3, max_depth=6, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.5, max_depth=9
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.5, max_depth=9, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=1, max_depth=3
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=1, max_depth=3, total=   3.9s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.001, max_depth=6
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.001, max_depth=6, total=   3.9s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.01, max_depth=8
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.01, max_depth=8, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.1, max_depth=3
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.1, max_depth=3, total=   3.9s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.2, max_depth=5
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.2, max_depth=5, total=   3.9s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.3, max_depth=8
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.3, max_depth=8, total=   3.7s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.5, max_depth=9
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.5, max_depth=9, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=1, max_depth=3
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=1, max_depth=3, total=   3.7s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.001, max_depth=4
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.001, max_depth=4, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.01, max_depth=7
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.01, max_depth=7, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.05, max_depth=9
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.05, max_depth=9, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.2, max_depth=4
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.2, max_depth=4, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.3, max_depth=6
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.3, max_depth=6, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.5, max_depth=8
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.5, max_depth=8, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=1, max_depth=3
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=1, max_depth=3, total=   3.9s
# [CV] booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.001, max_depth=6
# [CV]  booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.001, max_depth=6, total=   4.0s
# [CV] booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.01, max_depth=8
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.01, max_depth=9, total=   3.9s
# [CV] booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.1, max_depth=4
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.1, max_depth=4, total=   3.9s
# [CV] booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.2, max_depth=6
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.2, max_depth=6, total=   3.8s
# [CV] booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.3, max_depth=9
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.3, max_depth=9, total=   3.8s
# [CV] booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.75, max_depth=3
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.75, max_depth=3, total=   3.9s
# [CV] booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=1, max_depth=5
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=1, max_depth=5, total=   3.9s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.001, max_depth=7
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.001, max_depth=7, total=   4.0s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.01, max_depth=10
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.01, max_depth=10, total=   3.9s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.1, max_depth=4
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.1, max_depth=4, total=   3.9s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.2, max_depth=6
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.2, max_depth=6, total=   4.0s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.3, max_depth=9
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.3, max_depth=9, total=   4.0s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.75, max_depth=4
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.75, max_depth=4, total=   3.8s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=1, max_depth=7
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=1, max_depth=7, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.001, max_depth=9
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.001, max_depth=9, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.05, max_depth=3
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.05, max_depth=3, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.1, max_depth=5
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.1, max_depth=5, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.2, max_depth=8
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.2, max_depth=8, total=   3.8s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.3, max_depth=10
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.3, max_depth=10, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.75, max_depth=5
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.75, max_depth=5, total=   4.1s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=1, max_depth=8
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=1, max_depth=8, total=   3.6s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.001, max_depth=9
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.001, max_depth=9, total=   3.8s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.05, max_depth=3
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.05, max_depth=3, total=   4.1s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.1, max_depth=6
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.1, max_depth=6, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.2, max_depth=8
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.2, max_depth=8, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.5, max_depth=3
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.5, max_depth=3, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.75, max_depth=5
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.75, max_depth=5, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=1, max_depth=7
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=1, max_depth=7, total=   3.9s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.001, max_depth=10
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.001, max_depth=10, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.05, max_depth=4
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.05, max_depth=4, total=   3.7s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.1, max_depth=6
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.1, max_depth=6, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.2, max_depth=8
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.2, max_depth=8, total=   3.5s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.3, max_depth=10
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.3, max_depth=10, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.75, max_depth=4
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.75, max_depth=4, total=   3.9s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=1, max_depth=7
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=1, max_depth=7, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.001, max_depth=9
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.001, max_depth=9, total=   3.9s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.05, max_depth=3
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.05, max_depth=3, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.1, max_depth=5
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.1, max_depth=5, total=   3.9s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.2, max_depth=7
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.2, max_depth=7, total=   3.9s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.3, max_depth=10
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.3, max_depth=10, total=   3.7s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.75, max_depth=4
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.75, max_depth=4, total=   3.9s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=1, max_depth=6
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=1, max_depth=6, total=   3.9s
# [CV] booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.001, max_depth=8
# [CV]  booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.001, max_depth=8, total=   3.9s
# [CV] booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.05, max_depth=3
# [CV]  booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.05, max_depth=3, total=   3.8s
# [CV] booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.05, max_depth=3
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.05, max_depth=3, total=   4.0s
# [CV] booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.1, max_depth=5
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.1, max_depth=5, total=   3.8s
# [CV] booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.2, max_depth=7
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.2, max_depth=7, total=   3.8s
# [CV] booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.3, max_depth=10
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.3, max_depth=10, total=   3.8s
# [CV] booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.75, max_depth=4
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.75, max_depth=4, total=   3.9s
# [CV] booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=1, max_depth=6
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=1, max_depth=6, total=   3.9s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.001, max_depth=8
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.001, max_depth=8, total=   3.9s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.01, max_depth=10
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.01, max_depth=10, total=   3.9s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.1, max_depth=5
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.1, max_depth=5, total=   4.1s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.2, max_depth=9
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.2, max_depth=9, total=   4.1s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.5, max_depth=4
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.5, max_depth=4, total=   4.0s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.75, max_depth=6
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.75, max_depth=6, total=   4.0s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=1, max_depth=9
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=1, max_depth=9, total=   3.8s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.01, max_depth=3
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.01, max_depth=3, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.05, max_depth=5
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.05, max_depth=5, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.1, max_depth=8
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.1, max_depth=8, total=   4.0s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.2, max_depth=10
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.2, max_depth=10, total=   3.8s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.5, max_depth=5
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.5, max_depth=5, total=   3.8s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.75, max_depth=6
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.75, max_depth=6, total=   4.2s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=1, max_depth=9
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=1, max_depth=9, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.01, max_depth=4
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.01, max_depth=4, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.05, max_depth=6
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.05, max_depth=6, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.1, max_depth=9
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.1, max_depth=9, total=   3.8s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.3, max_depth=3
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.3, max_depth=3, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.5, max_depth=6
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.5, max_depth=6, total=   3.8s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.75, max_depth=8
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.75, max_depth=8, total=   3.8s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=1, max_depth=9
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=1, max_depth=9, total=   4.0s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.01, max_depth=4
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.01, max_depth=4, total=   3.9s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.05, max_depth=6
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.05, max_depth=6, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.1, max_depth=9
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.1, max_depth=9, total=   3.6s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.3, max_depth=3
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.3, max_depth=3, total=   4.0s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.5, max_depth=5
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.5, max_depth=5, total=   3.9s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.75, max_depth=7
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.75, max_depth=7, total=   3.6s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=1, max_depth=10
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=1, max_depth=10, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.01, max_depth=4
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.01, max_depth=4, total=   3.9s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.05, max_depth=7
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.05, max_depth=7, total=   4.0s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.1, max_depth=9
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.1, max_depth=9, total=   3.9s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.3, max_depth=3
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.3, max_depth=3, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.5, max_depth=5
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.5, max_depth=5, total=   3.9s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.75, max_depth=7
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.75, max_depth=7, total=   3.9s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=1, max_depth=9
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=1, max_depth=9, total=   3.9s
# [CV] booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.01, max_depth=3
# [CV]  booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.01, max_depth=3, total=   3.9s
# [CV] booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.05, max_depth=6
# [CV]  booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.05, max_depth=6, total=   3.8s
# [CV] booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.1, max_depth=9
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.1, max_depth=9, total=   3.9s
# [CV] booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.3, max_depth=3
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.3, max_depth=3, total=   3.8s
# [CV] booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.5, max_depth=5
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.5, max_depth=5, total=   3.9s
# [CV] booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.75, max_depth=7
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.75, max_depth=7, total=   3.9s
# [CV] booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=1, max_depth=10
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=1, max_depth=10, total=   3.9s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.01, max_depth=4
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.01, max_depth=4, total=   3.9s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.05, max_depth=7
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.05, max_depth=7, total=   3.9s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.1, max_depth=10
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.1, max_depth=10, total=   4.0s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.3, max_depth=5
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.3, max_depth=5, total=   4.1s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.5, max_depth=8
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.5, max_depth=8, total=   3.6s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.75, max_depth=9
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.75, max_depth=9, total=   3.7s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.001, max_depth=3
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.001, max_depth=3, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.01, max_depth=5
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.01, max_depth=5, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.05, max_depth=8
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.05, max_depth=8, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.1, max_depth=10
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.1, max_depth=10, total=   4.0s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.3, max_depth=4
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.3, max_depth=4, total=   3.8s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.5, max_depth=7
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.5, max_depth=7, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.75, max_depth=9
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.75, max_depth=9, total=   4.2s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.001, max_depth=3
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.001, max_depth=3, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.01, max_depth=6
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.01, max_depth=6, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.05, max_depth=8
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.05, max_depth=8, total=   3.8s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.1, max_depth=10
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.1, max_depth=10, total=   3.8s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.3, max_depth=5
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.3, max_depth=5, total=   3.8s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.5, max_depth=7
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.5, max_depth=7, total=   4.0s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.75, max_depth=10
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.75, max_depth=10, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.001, max_depth=4
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.001, max_depth=4, total=   3.9s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.01, max_depth=6
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.01, max_depth=6, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.05, max_depth=8
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.05, max_depth=8, total=   3.7s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.1, max_depth=10
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.1, max_depth=10, total=   4.0s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.3, max_depth=4
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.3, max_depth=4, total=   3.9s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.5, max_depth=7
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.5, max_depth=7, total=   3.9s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.75, max_depth=9
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.75, max_depth=9, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.001, max_depth=3
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.001, max_depth=3, total=   3.9s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.01, max_depth=6
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.01, max_depth=6, total=   3.7s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.05, max_depth=8
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.05, max_depth=8, total=   3.6s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.1, max_depth=10
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.1, max_depth=10, total=   3.7s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.3, max_depth=4
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.3, max_depth=4, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.5, max_depth=6
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.5, max_depth=6, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.75, max_depth=8
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.75, max_depth=8, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=1, max_depth=10
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=1, max_depth=10, total=   3.9s
# [CV] booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.01, max_depth=3
# [CV]  booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.01, max_depth=3, total=   3.9s
# [CV] booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.05, max_depth=6
# [CV]  booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.05, max_depth=6, total=   3.8s
# [CV] booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.1, max_depth=9
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.1, max_depth=10, total=   3.9s
# [CV] booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.3, max_depth=4
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.3, max_depth=4, total=   3.8s
# [CV] booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.5, max_depth=7
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.5, max_depth=7, total=   3.9s
# [CV] booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.75, max_depth=10
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.75, max_depth=10, total=   3.7s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.001, max_depth=3
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.001, max_depth=3, total=   4.0s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.01, max_depth=6
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.01, max_depth=6, total=   3.9s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.05, max_depth=8
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.05, max_depth=8, total=   3.6s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.2, max_depth=3
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.2, max_depth=3, total=   3.8s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.3, max_depth=5
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.3, max_depth=5, total=   4.1s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.5, max_depth=7
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.5, max_depth=7, total=   4.1s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.75, max_depth=10
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.75, max_depth=10, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.001, max_depth=5
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.001, max_depth=5, total=   3.8s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.01, max_depth=7
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.01, max_depth=7, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.05, max_depth=9
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.05, max_depth=9, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.2, max_depth=3
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.2, max_depth=3, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.3, max_depth=5
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.3, max_depth=5, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.5, max_depth=8
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.5, max_depth=8, total=   4.0s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.75, max_depth=10
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.75, max_depth=10, total=   4.1s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.001, max_depth=4
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.001, max_depth=4, total=   3.8s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.01, max_depth=7
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.01, max_depth=7, total=   3.4s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.05, max_depth=8
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.05, max_depth=8, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.2, max_depth=3
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.2, max_depth=3, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.3, max_depth=5
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.3, max_depth=5, total=   3.8s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.5, max_depth=8
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.5, max_depth=8, total=   4.1s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.75, max_depth=10
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.75, max_depth=10, total=   3.7s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.001, max_depth=5
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.001, max_depth=5, total=   3.6s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.01, max_depth=7
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.01, max_depth=7, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.05, max_depth=8
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.05, max_depth=8, total=   3.9s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.2, max_depth=3
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.2, max_depth=3, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.3, max_depth=5
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.3, max_depth=5, total=   4.0s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.5, max_depth=7
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.5, max_depth=7, total=   3.6s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.75, max_depth=9
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.75, max_depth=9, total=   3.5s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.001, max_depth=3
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.001, max_depth=3, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.01, max_depth=5
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.01, max_depth=5, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.05, max_depth=7
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.05, max_depth=7, total=   4.0s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.1, max_depth=10
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.1, max_depth=10, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.3, max_depth=5
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.3, max_depth=5, total=   3.9s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.5, max_depth=7
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.5, max_depth=7, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.75, max_depth=9
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.75, max_depth=9, total=   3.9s
# [CV] booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.001, max_depth=3
# [CV]  booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.001, max_depth=3, total=   4.0s
# [CV] booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.01, max_depth=5
# [CV]  booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.01, max_depth=5, total=   3.9s
# [CV] booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.05, max_depth=7
# [CV]  booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.05, max_depth=7, total=   3.9s
# [CV] booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.1, max_depth=9
# [CV]  booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.1, max_depth=9, total=   3.9s
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.2, max_depth=6, total=   3.8s
# [CV] booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.3, max_depth=8
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.3, max_depth=8, total=   3.8s
# [CV] booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.5, max_depth=10
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.5, max_depth=10, total=   3.9s
# [CV] booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=1, max_depth=4
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=1, max_depth=4, total=   3.9s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.001, max_depth=6
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.001, max_depth=6, total=   3.8s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.01, max_depth=8
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.01, max_depth=8, total=   3.9s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.1, max_depth=3
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.1, max_depth=3, total=   3.5s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.2, max_depth=5
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.2, max_depth=5, total=   4.0s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.3, max_depth=8
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.3, max_depth=8, total=   4.1s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.75, max_depth=3
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.75, max_depth=3, total=   3.8s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=1, max_depth=5
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=1, max_depth=5, total=   3.8s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.001, max_depth=6
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.001, max_depth=6, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.01, max_depth=9
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.01, max_depth=9, total=   3.7s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.1, max_depth=3
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.1, max_depth=3, total=   4.0s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.2, max_depth=6
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.2, max_depth=6, total=   3.8s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.3, max_depth=9
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.3, max_depth=9, total=   3.8s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.75, max_depth=3
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.75, max_depth=3, total=   4.1s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=1, max_depth=5
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=1, max_depth=5, total=   4.0s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.001, max_depth=7
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.001, max_depth=7, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.01, max_depth=9
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.01, max_depth=9, total=   3.5s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.1, max_depth=3
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.1, max_depth=3, total=   3.8s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.2, max_depth=6
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.2, max_depth=6, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.3, max_depth=8
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.3, max_depth=8, total=   3.8s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.5, max_depth=10
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.5, max_depth=10, total=   4.0s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=1, max_depth=5
# [CV]  booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=1, max_depth=5, total=   3.9s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.001, max_depth=7
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.001, max_depth=7, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.01, max_depth=9
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.01, max_depth=9, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.1, max_depth=4
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.1, max_depth=4, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.2, max_depth=6
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.2, max_depth=6, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.3, max_depth=9
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.3, max_depth=9, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.75, max_depth=3
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=0.75, max_depth=3, total=   3.9s
# [CV] booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=1, max_depth=5
# [CV]  booster=gblinear, gamma=10, grow_policy=depthwise, learning_rate=1, max_depth=5, total=   3.7s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.001, max_depth=6
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.001, max_depth=6, total=   3.9s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.01, max_depth=8
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.01, max_depth=8, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.1, max_depth=3
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.1, max_depth=3, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.2, max_depth=5
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.2, max_depth=5, total=   3.9s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.3, max_depth=8
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.3, max_depth=8, total=   3.8s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.5, max_depth=10
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=0.5, max_depth=10, total=   3.9s
# [CV] booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=1, max_depth=4
# [CV]  booster=gblinear, gamma=10, grow_policy=lossguide, learning_rate=1, max_depth=4, total=   3.9s
# [CV] booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.001, max_depth=7
# [CV]  booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.001, max_depth=7, total=   4.0s
# [CV] booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.01, max_depth=9
# [CV]  booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.01, max_depth=9, total=   3.9s
# [CV] booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.1, max_depth=4
# [CV]  booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.1, max_depth=4, total=   3.8s
# [CV] booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.2, max_depth=6
# [CV]  booster=gblinear, gamma=100, grow_policy=depthwise, learning_rate=0.2, max_depth=6, total=   3.8s
# [CV] booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.2, max_depth=9
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.2, max_depth=9, total=   3.8s
# [CV] booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.5, max_depth=4
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.5, max_depth=4, total=   3.8s
# [CV] booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.75, max_depth=6
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=0.75, max_depth=6, total=   3.9s
# [CV] booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=1, max_depth=8
# [CV]  booster=gblinear, gamma=1, grow_policy=depthwise, learning_rate=1, max_depth=8, total=   3.9s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.01, max_depth=3
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.01, max_depth=3, total=   3.9s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.05, max_depth=5
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.05, max_depth=5, total=   3.7s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.1, max_depth=7
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.1, max_depth=7, total=   3.5s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.2, max_depth=7
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.2, max_depth=7, total=   4.0s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.3, max_depth=9
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.3, max_depth=9, total=   3.9s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.75, max_depth=4
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=0.75, max_depth=4, total=   3.7s
# [CV] booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=1, max_depth=6
# [CV]  booster=gblinear, gamma=1, grow_policy=lossguide, learning_rate=1, max_depth=6, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.001, max_depth=8
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.001, max_depth=8, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.05, max_depth=3
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.05, max_depth=3, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.1, max_depth=4
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.1, max_depth=4, total=   3.9s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.2, max_depth=7
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.2, max_depth=7, total=   3.8s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.3, max_depth=10
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.3, max_depth=10, total=   3.8s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.75, max_depth=5
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=0.75, max_depth=5, total=   4.1s
# [CV] booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=1, max_depth=7
# [CV]  booster=gblinear, gamma=5, grow_policy=depthwise, learning_rate=1, max_depth=7, total=   3.7s
# [CV] booster=gblinear, gamma=5, grow_policy=lossguide, learning_rate=0.001, max_depth=9
# ...
# [CV] booster=dart, gamma=1, grow_policy=depthwise, learning_rate=0.2, max_depth=6
# [CV]  booster=dart, gamma=1, grow_policy=depthwise, learning_rate=0.2, max_depth=6, total=  31.1s
# [CV] booster=dart, gamma=1, grow_policy=depthwise, learning_rate=0.3, max_depth=9
# [CV]  booster=dart, gamma=1, grow_policy=depthwise, learning_rate=0.3, max_depth=9, total=  36.9s
# [CV] booster=dart, gamma=1, grow_policy=depthwise, learning_rate=0.75, max_depth=7
# [CV]  booster=dart, gamma=1, grow_policy=depthwise, learning_rate=0.75, max_depth=7, total=  32.1s
# [CV] booster=dart, gamma=1, grow_policy=lossguide, learning_rate=0.001, max_depth=3
# [CV]  booster=dart, gamma=1, grow_policy=lossguide, learning_rate=0.001, max_depth=3, total=  20.7s
# [CV] booster=dart, gamma=1, grow_policy=lossguide, learning_rate=0.001, max_depth=10
# [CV]  booster=dart, gamma=1, grow_policy=lossguide, learning_rate=0.001, max_depth=10, total=  49.1s
# [CV] booster=dart, gamma=1, grow_policy=lossguide, learning_rate=0.05, max_depth=10
# [CV]  booster=dart, gamma=1, grow_policy=lossguide, learning_rate=0.05, max_depth=10, total=  39.0s
# [CV] booster=dart, gamma=1, grow_policy=lossguide, learning_rate=0.2, max_depth=8
# [CV]  booster=dart, gamma=1, grow_policy=lossguide, learning_rate=0.2, max_depth=8, total=  34.8s
# [CV] booster=dart, gamma=1, grow_policy=lossguide, learning_rate=0.5, max_depth=3
# [CV]  booster=dart, gamma=1, grow_policy=lossguide, learning_rate=0.5, max_depth=3, total=  19.2s
# [CV] booster=dart, gamma=1, grow_policy=lossguide, learning_rate=0.75, max_depth=3
# [CV]  booster=dart, gamma=1, grow_policy=lossguide, learning_rate=0.75, max_depth=3, total=  18.4s
# [CV] booster=dart, gamma=1, grow_policy=lossguide, learning_rate=0.75, max_depth=10
# [CV]  booster=dart, gamma=1, grow_policy=lossguide, learning_rate=0.75, max_depth=10, total=  33.8s
# [CV] booster=dart, gamma=5, grow_policy=depthwise, learning_rate=0.001, max_depth=8
# [CV]  booster=dart, gamma=5, grow_policy=depthwise, learning_rate=0.001, max_depth=8, total=  42.5s
# [CV] booster=dart, gamma=5, grow_policy=depthwise, learning_rate=0.05, max_depth=5
# [CV]  booster=dart, gamma=5, grow_policy=depthwise, learning_rate=0.05, max_depth=5, total=  27.5s
# [CV] booster=dart, gamma=5, grow_policy=depthwise, learning_rate=0.1, max_depth=6
# [CV]  booster=dart, gamma=5, grow_policy=depthwise, learning_rate=0.1, max_depth=6, total=  31.2s
# [CV] booster=dart, gamma=5, grow_policy=depthwise, learning_rate=0.2, max_depth=9
# [CV]  booster=dart, gamma=5, grow_policy=depthwise, learning_rate=0.2, max_depth=9, total=  40.9s
# [CV] booster=dart, gamma=5, grow_policy=depthwise, learning_rate=0.5, max_depth=7
# [CV]  booster=dart, gamma=5, grow_policy=depthwise, learning_rate=0.5, max_depth=7, total=  35.3s
# [CV] booster=dart, gamma=5, grow_policy=depthwise, learning_rate=1, max_depth=3
# [CV]  booster=dart, gamma=5, grow_policy=depthwise, learning_rate=1, max_depth=3, total=  18.8s
# [CV] booster=dart, gamma=5, grow_policy=depthwise, learning_rate=1, max_depth=10
# [CV]  booster=dart, gamma=5, grow_policy=depthwise, learning_rate=1, max_depth=10, total=  41.2s
# [CV] booster=dart, gamma=5, grow_policy=lossguide, learning_rate=0.01, max_depth=7
# [CV]  booster=dart, gamma=5, grow_policy=lossguide, learning_rate=0.01, max_depth=7, total=  36.6s
# [CV] booster=dart, gamma=5, grow_policy=lossguide, learning_rate=0.1, max_depth=3
# [CV]  booster=dart, gamma=5, grow_policy=lossguide, learning_rate=0.1, max_depth=3, total=  20.9s
# [CV] booster=dart, gamma=5, grow_policy=lossguide, learning_rate=0.1, max_depth=10
# [CV]  booster=dart, gamma=5, grow_policy=lossguide, learning_rate=0.1, max_depth=10, total=  43.0s
# [CV] booster=dart, gamma=5, grow_policy=lossguide, learning_rate=0.3, max_depth=8
# [CV]  booster=dart, gamma=5, grow_policy=lossguide, learning_rate=0.3, max_depth=8, total=  38.3s
# [CV] booster=dart, gamma=5, grow_policy=lossguide, learning_rate=0.75, max_depth=5
# [CV]  booster=dart, gamma=5, grow_policy=lossguide, learning_rate=0.75, max_depth=5, total=  27.8s
# [CV] booster=dart, gamma=5, grow_policy=lossguide, learning_rate=1, max_depth=6
# [CV]  booster=dart, gamma=5, grow_policy=lossguide, learning_rate=1, max_depth=6, total=  32.8s
# [CV] booster=dart, gamma=10, grow_policy=depthwise, learning_rate=0.001, max_depth=10
# [CV]  booster=dart, gamma=10, grow_policy=depthwise, learning_rate=0.001, max_depth=10, total=  49.2s
# [CV] booster=dart, gamma=10, grow_policy=depthwise, learning_rate=0.05, max_depth=9
# [CV]  booster=dart, gamma=10, grow_policy=depthwise, learning_rate=0.05, max_depth=9, total=  41.2s
# [CV] booster=dart, gamma=10, grow_policy=depthwise, learning_rate=0.2, max_depth=7
# [CV]  booster=dart, gamma=10, grow_policy=depthwise, learning_rate=0.2, max_depth=7, total=  35.7s
# [CV] booster=dart, gamma=10, grow_policy=depthwise, learning_rate=0.5, max_depth=3
# [CV]  booster=dart, gamma=10, grow_policy=depthwise, learning_rate=0.5, max_depth=3, total=  20.4s
# [CV] booster=dart, gamma=10, grow_policy=depthwise, learning_rate=0.5, max_depth=9
# [CV]  booster=dart, gamma=10, grow_policy=depthwise, learning_rate=0.5, max_depth=9, total=  41.4s
# [CV] booster=dart, gamma=10, grow_policy=depthwise, learning_rate=1, max_depth=7
# [CV]  booster=dart, gamma=10, grow_policy=depthwise, learning_rate=1, max_depth=7, total=  36.8s
# [CV] booster=dart, gamma=10, grow_policy=lossguide, learning_rate=0.01, max_depth=3
# [CV]  booster=dart, gamma=10, grow_policy=lossguide, learning_rate=0.01, max_depth=3, total=  21.3s
# [CV] booster=dart, gamma=10, grow_policy=lossguide, learning_rate=0.01, max_depth=9
# [CV]  booster=dart, gamma=10, grow_policy=lossguide, learning_rate=0.01, max_depth=9, total=  43.3s
# [CV] booster=dart, gamma=10, grow_policy=lossguide, learning_rate=0.1, max_depth=8
# [CV] booster=dart, gamma=0, grow_policy=depthwise, learning_rate=0.2, max_depth=7
# [CV]  booster=dart, gamma=0, grow_policy=depthwise, learning_rate=0.2, max_depth=7, total=  28.1s
# [CV] booster=dart, gamma=0, grow_policy=depthwise, learning_rate=0.3, max_depth=10
# [CV]  booster=dart, gamma=0, grow_policy=depthwise, learning_rate=0.3, max_depth=10, total=  23.8s
# [CV] booster=dart, gamma=0, grow_policy=depthwise, learning_rate=0.75, max_depth=8
# [CV]  booster=dart, gamma=0, grow_policy=depthwise, learning_rate=0.75, max_depth=8, total=  16.0s
# [CV] booster=dart, gamma=0, grow_policy=lossguide, learning_rate=0.001, max_depth=3
# [CV]  booster=dart, gamma=0, grow_policy=lossguide, learning_rate=0.001, max_depth=3, total=  21.1s
# [CV] booster=dart, gamma=0, grow_policy=lossguide, learning_rate=0.01, max_depth=6
# [CV]  booster=dart, gamma=0, grow_policy=lossguide, learning_rate=0.01, max_depth=6, total=  35.2s
# [CV] booster=dart, gamma=0, grow_policy=lossguide, learning_rate=0.05, max_depth=8
# [CV]  booster=dart, gamma=0, grow_policy=lossguide, learning_rate=0.05, max_depth=8, total=  37.8s
# [CV] booster=dart, gamma=0, grow_policy=lossguide, learning_rate=0.2, max_depth=5
# [CV]  booster=dart, gamma=0, grow_policy=lossguide, learning_rate=0.2, max_depth=5, total=  26.6s
# [CV] booster=dart, gamma=0, grow_policy=lossguide, learning_rate=0.3, max_depth=8
# [CV]  booster=dart, gamma=0, grow_policy=lossguide, learning_rate=0.3, max_depth=8, total=  24.6s
# [CV] booster=dart, gamma=0, grow_policy=lossguide, learning_rate=0.75, max_depth=4
# [CV]  booster=dart, gamma=0, grow_policy=lossguide, learning_rate=0.75, max_depth=4, total=  15.9s
# [CV] booster=dart, gamma=0, grow_policy=lossguide, learning_rate=1, max_depth=5
# [CV]  booster=dart, gamma=0, grow_policy=lossguide, learning_rate=1, max_depth=5, total=  14.3s
# [CV] booster=dart, gamma=1, grow_policy=depthwise, learning_rate=0.01, max_depth=3
# [CV]  booster=dart, gamma=1, grow_policy=depthwise, learning_rate=0.01, max_depth=3, total=  21.7s
# [CV] booster=dart, gamma=1, grow_policy=depthwise, learning_rate=0.01, max_depth=8
# [CV]  booster=dart, gamma=1, grow_policy=depthwise, learning_rate=0.01, max_depth=8, total=  41.1s
# [CV] booster=dart, gamma=1, grow_policy=depthwise, learning_rate=0.1, max_depth=5
# [CV]  booster=dart, gamma=1, grow_policy=depthwise, learning_rate=0.1, max_depth=5, total=  29.4s
# [CV] booster=dart, gamma=1, grow_policy=depthwise, learning_rate=0.2, max_depth=8
# [CV]  booster=dart, gamma=1, grow_policy=depthwise, learning_rate=0.2, max_depth=8, total=  35.4s
# [CV] booster=dart, gamma=1, grow_policy=depthwise, learning_rate=0.5, max_depth=4
# [CV]  booster=dart, gamma=1, grow_policy=depthwise, learning_rate=0.5, max_depth=4, total=  23.6s
# [CV] booster=dart, gamma=1, grow_policy=depthwise, learning_rate=0.75, max_depth=4
# [CV]  booster=dart, gamma=1, grow_policy=depthwise, learning_rate=0.75, max_depth=4, total=  23.6s
# [CV] booster=dart, gamma=1, grow_policy=depthwise, learning_rate=1, max_depth=5
# [CV]  booster=dart, gamma=1, grow_policy=depthwise, learning_rate=1, max_depth=5, total=  26.4s
# [CV] booster=dart, gamma=1, grow_policy=lossguide, learning_rate=0.001, max_depth=8
# [CV]  booster=dart, gamma=1, grow_policy=lossguide, learning_rate=0.001, max_depth=8, total=  46.3s
# [CV] booster=dart, gamma=1, grow_policy=lossguide, learning_rate=0.05, max_depth=6
# [CV]  booster=dart, gamma=1, grow_policy=lossguide, learning_rate=0.05, max_depth=6, total=  31.7s
# [CV] booster=dart, gamma=1, grow_policy=lossguide, learning_rate=0.1, max_depth=10
# [CV]  booster=dart, gamma=1, grow_policy=lossguide, learning_rate=0.1, max_depth=10, total=  39.2s
# [CV] booster=dart, gamma=1, grow_policy=lossguide, learning_rate=0.3, max_depth=7
# [CV]  booster=dart, gamma=1, grow_policy=lossguide, learning_rate=0.3, max_depth=7, total=  32.7s
# [CV] booster=dart, gamma=1, grow_policy=lossguide, learning_rate=0.5, max_depth=10
# [CV]  booster=dart, gamma=1, grow_policy=lossguide, learning_rate=0.5, max_depth=10, total=  36.6s
# [CV] booster=dart, gamma=1, grow_policy=lossguide, learning_rate=1, max_depth=9
# [CV]  booster=dart, gamma=1, grow_policy=lossguide, learning_rate=1, max_depth=9, total=  33.3s
# [CV] booster=dart, gamma=5, grow_policy=depthwise, learning_rate=0.01, max_depth=5
# [CV]  booster=dart, gamma=5, grow_policy=depthwise, learning_rate=0.01, max_depth=5, total=  29.8s
# [CV] booster=dart, gamma=5, grow_policy=depthwise, learning_rate=0.05, max_depth=6
# [CV]  booster=dart, gamma=5, grow_policy=depthwise, learning_rate=0.05, max_depth=6, total=  31.6s
# [CV] booster=dart, gamma=5, grow_policy=depthwise, learning_rate=0.1, max_depth=10
# [CV]  booster=dart, gamma=5, grow_policy=depthwise, learning_rate=0.1, max_depth=10, total=  40.2s
# [CV] booster=dart, gamma=5, grow_policy=depthwise, learning_rate=0.3, max_depth=7
# [CV]  booster=dart, gamma=5, grow_policy=depthwise, learning_rate=0.3, max_depth=7, total=  35.2s
# [CV] booster=dart, gamma=5, grow_policy=depthwise, learning_rate=0.75, max_depth=3
# [CV]  booster=dart, gamma=5, grow_policy=depthwise, learning_rate=0.75, max_depth=3, total=  19.4s
# [CV] booster=dart, gamma=5, grow_policy=depthwise, learning_rate=0.75, max_depth=10
# [CV]  booster=dart, gamma=5, grow_policy=depthwise, learning_rate=0.75, max_depth=10, total=  41.1s
# [CV] booster=dart, gamma=5, grow_policy=lossguide, learning_rate=0.001, max_depth=8
# [CV]  booster=dart, gamma=5, grow_policy=lossguide, learning_rate=0.001, max_depth=8, total=  44.3s
# [CV] booster=dart, gamma=5, grow_policy=lossguide, learning_rate=0.05, max_depth=5
# [CV]  booster=dart, gamma=5, grow_policy=lossguide, learning_rate=0.05, max_depth=5, total=  28.5s
# [CV] booster=dart, gamma=5, grow_policy=lossguide, learning_rate=0.1, max_depth=7
# [CV]  booster=dart, gamma=5, grow_policy=lossguide, learning_rate=0.1, max_depth=7, total=  35.5s
# [CV] booster=dart, gamma=5, grow_policy=lossguide, learning_rate=0.3, max_depth=3
# [CV]  booster=dart, gamma=5, grow_policy=lossguide, learning_rate=0.3, max_depth=3, total=  20.1s
# [CV] booster=dart, gamma=5, grow_policy=lossguide, learning_rate=0.3, max_depth=9
# [CV]  booster=dart, gamma=5, grow_policy=lossguide, learning_rate=0.3, max_depth=9, total=  40.9s
# [CV] booster=dart, gamma=5, grow_policy=lossguide, learning_rate=0.75, max_depth=8
# [CV]  booster=dart, gamma=5, grow_policy=lossguide, learning_rate=0.75, max_depth=8, total=  39.5s
# [CV] booster=dart, gamma=10, grow_policy=depthwise, learning_rate=0.001, max_depth=5
# [CV]  booster=dart, gamma=10, grow_policy=depthwise, learning_rate=0.001, max_depth=5, total=  31.9s
# [CV] booster=dart, gamma=10, grow_policy=depthwise, learning_rate=0.01, max_depth=8
# [CV]  booster=dart, gamma=10, grow_policy=depthwise, learning_rate=0.01, max_depth=8, total=  40.9s
# [CV] booster=dart, gamma=10, grow_policy=depthwise, learning_rate=0.1, max_depth=5
# [CV]  booster=dart, gamma=10, grow_policy=depthwise, learning_rate=0.1, max_depth=5, total=  29.5s
# [CV] booster=dart, gamma=10, grow_policy=depthwise, learning_rate=0.2, max_depth=6
# [CV]  booster=dart, gamma=10, grow_policy=depthwise, learning_rate=0.2, max_depth=6, total=  32.7s
# [CV] booster=dart, gamma=10, grow_policy=depthwise, learning_rate=0.3, max_depth=9
# [CV]  booster=dart, gamma=10, grow_policy=depthwise, learning_rate=0.3, max_depth=9, total=  42.9s
# [CV] booster=dart, gamma=10, grow_policy=depthwise, learning_rate=0.75, max_depth=8
# [CV]  booster=dart, gamma=10, grow_policy=depthwise, learning_rate=0.75, max_depth=8, total=  39.9s
# [CV] booster=dart, gamma=10, grow_policy=lossguide, learning_rate=0.001, max_depth=5
# [CV]  booster=dart, gamma=10, grow_policy=lossguide, learning_rate=0.001, max_depth=5, total=  33.0s
# [CV] booster=dart, gamma=10, grow_policy=lossguide, learning_rate=0.01, max_depth=8
# [CV]  booster=dart, gamma=10, grow_policy=lossguide, learning_rate=0.01, max_depth=8, total=  41.0s
# [CV] booster=dart, gamma=10, grow_policy=lossguide, learning_rate=0.1, max_depth=5
# [CV]  booster=dart, gamma=10, grow_policy=lossguide, learning_rate=0.1, max_depth=5, total=  29.5s
# [CV] booster=dart, gamma=10, grow_policy=lossguide, learning_rate=0.2, max_depth=6
# [Parallel(n_jobs=32)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=32)]: Done  98 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=32)]: Done 301 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=32)]: Done 584 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=32)]: Done 949 tasks      | elapsed: 12.0min
# [Parallel(n_jobs=32)]: Done 1394 tasks      | elapsed: 18.7min
# [Parallel(n_jobs=32)]: Done 1921 tasks      | elapsed: 26.7min
# [Parallel(n_jobs=32)]: Done 2528 tasks      | elapsed: 30.9min
# [Parallel(n_jobs=32)]: Done 3217 tasks      | elapsed: 32.3min
# [Parallel(n_jobs=32)]: Done 3986 tasks      | elapsed: 33.9min
# [Parallel(n_jobs=32)]: Done 4837 tasks      | elapsed: 41.9min
# [Parallel(n_jobs=32)]: Done 5768 tasks      | elapsed: 57.0min
# [Parallel(n_jobs=32)]: Done 6480 out of 6480 | elapsed: 68.9min finished
# GridSearchCV(cv=3, error_score='raise',
#              estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                      colsample_bylevel=1, colsample_bynode=1,
#                                      colsample_bytree=1, gamma=0,
#                                      learning_rate=0.1, max_delta_step=0,
#                                      max_depth=3, min_child_weight=1,
#                                      missing=None, n_estimators=100, n_jobs=1,
#                                      nthread=None, objective='multi:softmax',
#                                      random_state=0, reg_alpha=0, reg_lambda=1,
#                                      scale_...
#              iid='deprecated', n_jobs=32,
#              param_grid={'booster': ['gbtree', 'gblinear', 'dart'],
#                          'gamma': [0, 1, 5, 10, 100],
#                          'grow_policy': ['depthwise', 'lossguide'],
#                          'learning_rate': [0.001, 0.01, 0.05, 0.1, 0.2, 0.3,
#                                            0.5, 0.75, 1],
#                          'max_depth': range(3, 11)},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=make_scorer(recall_score, average=macro, zero_division=0),
#              verbose=2)

# %%
#!c1.32
gs32.best_score_, gs32.best_estimator_
# Out:
# (0.9691481655542757,
#  XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                colsample_bynode=1, colsample_bytree=1, gamma=0,
#                grow_policy='depthwise', learning_rate=0.3, max_delta_step=0,
#                max_depth=4, min_child_weight=1, missing=None, n_estimators=100,
#                n_jobs=1, nthread=None, objective='multi:softprob',
#                random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                seed=None, silent=None, subsample=1, verbosity=1))

# %%
#!c1.32
def save_sumbission(test_data, transformer, model, suffix):
    ids = test_data["id"].to_list()
    X_test = test_data.drop(["id"], axis=1)
    X_test = transformer.fit_transform(X_test)
    y_pred = model.predict(X_test)
    submission = pd.DataFrame({"id": ids, "crop": y_pred})
    submission.to_csv(f"submission_{suffix}.csv", index=None)

# %%
#!c1.32
save_sumbission(test, transformer, gs32.best_estimator_, "32")

# %%
#!c1.32
X_train, X_val, y_train, y_val = train_test_split(transformer.fit_transform(X), y, test_size=0.75, random_state=42)

# %%
#!c1.32
xgb_best = gs32.best_estimator_
xgb_best.set_params(eval_metric="mlogloss", n_estimators=500)
xgb_best.fit(X_train, y_train, eval_set=[(X_val, y_val)], early_stopping_rounds=10)
# Out:
# [0]	validation_0-mlogloss:1.36093
# Will train until validation_0-mlogloss hasn't improved in 10 rounds.
# [1]	validation_0-mlogloss:1.08031
# [2]	validation_0-mlogloss:0.894126
# [3]	validation_0-mlogloss:0.75725
# [4]	validation_0-mlogloss:0.64955
# [5]	validation_0-mlogloss:0.567716
# [6]	validation_0-mlogloss:0.498612
# [7]	validation_0-mlogloss:0.442068
# [8]	validation_0-mlogloss:0.39654
# [9]	validation_0-mlogloss:0.361551
# [10]	validation_0-mlogloss:0.33058
# [11]	validation_0-mlogloss:0.305997
# [12]	validation_0-mlogloss:0.284722
# [13]	validation_0-mlogloss:0.267003
# [14]	validation_0-mlogloss:0.255232
# [15]	validation_0-mlogloss:0.243205
# [16]	validation_0-mlogloss:0.230221
# [17]	validation_0-mlogloss:0.221683
# [18]	validation_0-mlogloss:0.211638
# [19]	validation_0-mlogloss:0.205751
# [20]	validation_0-mlogloss:0.199959
# [21]	validation_0-mlogloss:0.19534
# [22]	validation_0-mlogloss:0.190239
# [23]	validation_0-mlogloss:0.186693
# [24]	validation_0-mlogloss:0.183332
# [25]	validation_0-mlogloss:0.180053
# [26]	validation_0-mlogloss:0.177996
# [27]	validation_0-mlogloss:0.175531
# [28]	validation_0-mlogloss:0.173453
# [29]	validation_0-mlogloss:0.171677
# [30]	validation_0-mlogloss:0.169615
# [31]	validation_0-mlogloss:0.167457
# [32]	validation_0-mlogloss:0.166646
# [33]	validation_0-mlogloss:0.166053
# [34]	validation_0-mlogloss:0.164666
# [35]	validation_0-mlogloss:0.164299
# [36]	validation_0-mlogloss:0.162945
# [37]	validation_0-mlogloss:0.162445
# [38]	validation_0-mlogloss:0.163091
# [39]	validation_0-mlogloss:0.162116
# [40]	validation_0-mlogloss:0.161216
# [41]	validation_0-mlogloss:0.161081
# [42]	validation_0-mlogloss:0.159979
# [43]	validation_0-mlogloss:0.160618
# [44]	validation_0-mlogloss:0.159841
# [45]	validation_0-mlogloss:0.159407
# [46]	validation_0-mlogloss:0.159207
# [47]	validation_0-mlogloss:0.158973
# [48]	validation_0-mlogloss:0.158563
# [49]	validation_0-mlogloss:0.158571
# [50]	validation_0-mlogloss:0.158778
# [51]	validation_0-mlogloss:0.159007
# [52]	validation_0-mlogloss:0.158863
# [53]	validation_0-mlogloss:0.158704
# [54]	validation_0-mlogloss:0.15865
# [55]	validation_0-mlogloss:0.158627
# [56]	validation_0-mlogloss:0.158778
# [57]	validation_0-mlogloss:0.158322
# [58]	validation_0-mlogloss:0.158464
# [59]	validation_0-mlogloss:0.158372
# [60]	validation_0-mlogloss:0.158237
# [61]	validation_0-mlogloss:0.15847
# [62]	validation_0-mlogloss:0.158652
# [63]	validation_0-mlogloss:0.158676
# [64]	validation_0-mlogloss:0.158608
# [65]	validation_0-mlogloss:0.159038
# [66]	validation_0-mlogloss:0.159063
# [67]	validation_0-mlogloss:0.159245
# [68]	validation_0-mlogloss:0.159051
# [69]	validation_0-mlogloss:0.159003
# [70]	validation_0-mlogloss:0.159133
# Stopping. Best iteration:
# [60]	validation_0-mlogloss:0.158237
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, early_stopping_rounds=50,
#               eval_metric='mlogloss', gamma=0, grow_policy='depthwise',
#               learning_rate=0.3, max_delta_step=0, max_depth=4,
#               min_child_weight=1, missing=None, n_estimators=500, n_jobs=1,
#               nthread=None, objective='multi:softprob', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
#!c1.32
recall_score(y_val, xgb_best.predict(X_val), average="macro", zero_division=0)
# Out:
# 0.9500664756740308

# %%
#!c1.32
save_sumbission(test, transformer, xgb_best, "32_1")

# %%
#!c1.32
gs33_params = {
    "num_leaves": range(10, 31, 10),
    "max_depth": range(4, 11),
    "learning_rate": [0.001, 0.01, 0.1, 0.2, 0.5, 0.7, 1],
    "reg_lambda": [0, 1, 10]
}

gs33 = GridSearchCV(LGBMClassifier(boosting_type="dart", n_estimators=200),
                    gs33_params, random_state=42,
                    scoring=recall_scorer, cv=3, verbose=1, n_jobs=32)
gs33.fit(transformer.fit_transform(X), y)
# Out:
# Fitting 3 folds for each of 441 candidates, totalling 1323 fits
# [Parallel(n_jobs=32)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=32)]: Done 136 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=32)]: Done 386 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=32)]: Done 736 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=32)]: Done 1186 tasks      | elapsed: 15.9min
# [Parallel(n_jobs=32)]: Done 1323 out of 1323 | elapsed: 17.3min finished
# GridSearchCV(cv=3, error_score=nan,
#              estimator=LGBMClassifier(boosting_type='dart', class_weight=None,
#                                       colsample_bytree=1.0,
#                                       importance_type='split',
#                                       learning_rate=0.1, max_depth=-1,
#                                       min_child_samples=20,
#                                       min_child_weight=0.001,
#                                       min_split_gain=0.0, n_estimators=200,
#                                       n_jobs=-1, num_leaves=31, objective=None,
#                                       random_state=None, reg_alpha=0.0,
#                                       reg_lambda=0.0, silent=True,
#                                       subsample=1.0, subsample_for_bin=200000,
#                                       subsample_freq=0),
#              iid='deprecated', n_jobs=32,
#              param_grid={'learning_rate': [0.001, 0.01, 0.1, 0.2, 0.5, 0.7, 1],
#                          'max_depth': range(4, 11),
#                          'num_leaves': range(10, 31, 10),
#                          'reg_lambda': [0, 1, 10]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=make_scorer(recall_score, average=macro, zero_division=0),
#              verbose=1)

# %%
#!c1.32
gs33.best_score_, gs33.best_estimator_
# Out:
# (0.9731523592058261,
#  LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#                 importance_type='split', learning_rate=0.5, max_depth=8,
#                 min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                 n_estimators=200, n_jobs=-1, num_leaves=20, objective=None,
#                 random_state=None, reg_alpha=0.0, reg_lambda=0, silent=True,
#                 subsample=1.0, subsample_for_bin=200000, subsample_freq=0))

# %%
#!c1.32
save_sumbission(test, transformer, gs33.best_estimator_, "33")

# %%
#!c1.32
lgbm_best = LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
                importance_type='split', learning_rate=0.5, max_depth=8,
                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
                n_estimators=200, n_jobs=-1, num_leaves=20, objective=None,
                random_state=None, reg_alpha=0.0, reg_lambda=0, silent=True,
                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
lgbm_best.set_params(random_state=42)
gs_33_2 = GridSearchCV(lgbm_best, {"n_estimators": range(10, 501)},
                       scoring=recall_scorer, cv=3,
                       verbose=1, n_jobs=32)
gs_33_2.fit(transformer.fit_transform(X), y)
# Out:
# Fitting 3 folds for each of 491 candidates, totalling 1473 fits
# [Parallel(n_jobs=32)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=32)]: Done 136 tasks      | elapsed:   33.5s
# [Parallel(n_jobs=32)]: Done 386 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=32)]: Done 736 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=32)]: Done 1186 tasks      | elapsed: 22.3min
# [Parallel(n_jobs=32)]: Done 1473 out of 1473 | elapsed: 32.0min finished
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-fe58b98c515b> in <module>
#      10                        verbose=1, n_jobs=32)
#      11 gs_33_2.fit(transformer.fit_transform(X), y)
# ---> 12 gs33_2.best_score_, gs33_2.best_estimator_
#      13 #
#
# NameError: name 'gs33_2' is not defined

# %%
#!c1.32
gs_33_2.best_score_, gs_33_2.best_estimator_
# Out:
# (0.9730620213494628,
#  LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#                 importance_type='split', learning_rate=0.5, max_depth=8,
#                 min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                 n_estimators=287, n_jobs=-1, num_leaves=20, objective=None,
#                 random_state=42, reg_alpha=0.0, reg_lambda=0, silent=True,
#                 subsample=1.0, subsample_for_bin=200000, subsample_freq=0))

# %%
#!c1.32
save_sumbission(test, transformer, gs_33_2.best_estimator_, "33_2")

# %%
#!c1.32
gs34_params = {
    "n_estimators": range(3, 100, 3),
    "criterion": ["gini", "entropy"],
    "max_depth": range(3, 61, 3),
    "min_samples_split": range(5, 61, 5)
}

gs34 = GridSearchCV(RandomForestClassifier(random_state=42), gs34_params,
                    scoring=recall_scorer, cv=3, verbose=1, n_jobs=32)
gs34.fit(transformer.fit_transform(X), y)
# Out:
# Fitting 3 folds for each of 15840 candidates, totalling 47520 fits
# [Parallel(n_jobs=32)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=32)]: Done 136 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=32)]: Done 386 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=32)]: Done 736 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=32)]: Done 1186 tasks      | elapsed:   22.1s
# [Parallel(n_jobs=32)]: Done 1736 tasks      | elapsed:   37.5s
# [Parallel(n_jobs=32)]: Done 2386 tasks      | elapsed:   56.2s
# [Parallel(n_jobs=32)]: Done 3136 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=32)]: Done 3986 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=32)]: Done 4936 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=32)]: Done 5986 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=32)]: Done 7136 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=32)]: Done 8386 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=32)]: Done 9736 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=32)]: Done 11186 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=32)]: Done 12736 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=32)]: Done 14386 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=32)]: Done 16136 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=32)]: Done 17986 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=32)]: Done 19936 tasks      | elapsed: 13.0min
# [Parallel(n_jobs=32)]: Done 21986 tasks      | elapsed: 14.4min
# [Parallel(n_jobs=32)]: Done 24136 tasks      | elapsed: 15.9min
# [Parallel(n_jobs=32)]: Done 26386 tasks      | elapsed: 18.6min
# [Parallel(n_jobs=32)]: Done 28736 tasks      | elapsed: 22.6min
# [Parallel(n_jobs=32)]: Done 31186 tasks      | elapsed: 27.0min
# [Parallel(n_jobs=32)]: Done 33736 tasks      | elapsed: 31.6min
# [Parallel(n_jobs=32)]: Done 36386 tasks      | elapsed: 36.3min
# [Parallel(n_jobs=32)]: Done 39136 tasks      | elapsed: 41.2min
# [Parallel(n_jobs=32)]: Done 41986 tasks      | elapsed: 46.3min
# [Parallel(n_jobs=32)]: Done 44936 tasks      | elapsed: 51.5min
# [Parallel(n_jobs=32)]: Done 47520 out of 47520 | elapsed: 56.1min finished
# GridSearchCV(cv=3, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False, random_state=42,
#                                               verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=32,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(3, 61, 3),
#                          'min_samples_split': range(5, 61, 5),
#                          'n_estimators': range(3, 100, 3)},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=make_scorer(recall_score, average=macro, zero_division=0),
#              verbose=1)

# %%
#!c1.32
gs34.best_score_, gs34.best_estimator_
# Out:
# (0.9651392260237444,
#  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                         criterion='gini', max_depth=36, max_features='auto',
#                         max_leaf_nodes=None, max_samples=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=20,
#                         min_weight_fraction_leaf=0.0, n_estimators=93,
#                         n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                         warm_start=False))

# %%
#!c1.32
save_sumbission(test, transformer, gs34.best_estimator_, "34")

# %% [markdown]
# # 4. `sktime`

# %%
#!c1.32
from sktime.classification.feature_based import Catch22Classifier

# %%
#!c1.32
X_ts = df.loc[:, df.columns.str.contains("nd_mean_")]
y_ts = df["crop"]

# %%
#!c1.32
X_ts
# Out:
#       nd_mean_2021-04-16  nd_mean_2021-04-19  nd_mean_2021-04-22  \
# 0               0.072846            0.261778            0.062981
# 1               0.332928            0.287182            0.097138
# 2               0.013679            0.007055            0.120804
# 3               0.105976            0.052500            0.001917
# 4               0.130885            0.063492            0.024416
# ...                  ...                 ...                 ...
# 4825            0.028770            0.038282            0.255329
# 4826            0.035939            0.030722            0.033869
# 4827            0.191255            0.063581            0.140111
# 4828            0.291399            0.221428            0.007247
# 4829            0.226925            0.043076            0.058611
#
#       nd_mean_2021-04-26  nd_mean_2021-04-28  nd_mean_2021-05-02  \
# 0               0.104442            0.021096            0.052202
# 1               0.152467            0.075484            0.000000
# 2               0.037839            0.259125            0.000000
# 3               0.011531            0.042316            0.000000
# 4               0.000000            0.150671            0.046717
# ...                  ...                 ...                 ...
# 4825            0.148166            0.225421            0.479483
# 4826            0.029646            0.318387            0.247905
# 4827            0.323984            0.000000            0.005056
# 4828            0.055074            0.057781            0.187749
# 4829            0.440539            0.120169            0.138846
#
#       nd_mean_2021-05-04  nd_mean_2021-05-07  nd_mean_2021-05-16  \
# 0               0.158723            0.000000            0.484102
# 1               0.140326            0.163340            0.519456
# 2               0.037446            0.506516            0.000000
# 3               0.000000            0.043604            0.510271
# 4               0.254284            0.101479            0.000000
# ...                  ...                 ...                 ...
# 4825            0.071684            0.016856            0.407955
# 4826            0.265180            0.286298            0.578936
# 4827            0.092693            0.399439            0.006256
# 4828            0.112403            0.183555            0.504538
# 4829            0.020173            0.117669            0.266987
#
#       nd_mean_2021-05-17  ...  nd_mean_2021-05-19  nd_mean_2021-05-20  \
# 0               0.201013  ...            0.425571            0.108999
# 1               0.501486  ...            0.248935            0.134469
# 2               0.561541  ...            0.127633            0.084467
# 3               0.511552  ...            0.527583            0.000000
# 4               0.403379  ...            0.000000            0.206158
# ...                  ...  ...                 ...                 ...
# 4825            0.367435  ...            0.169733            0.001875
# 4826            0.420588  ...            0.041057            0.192014
# 4827            0.477546  ...            0.022025            0.085006
# 4828            0.721011  ...            0.490711            0.536825
# 4829            0.393695  ...            0.000000            0.085106
#
#       nd_mean_2021-06-04  nd_mean_2021-06-05  nd_mean_2021-06-10  \
# 0               0.118854            0.000000            0.000000
# 1               0.208268            0.000000            0.000000
# 2               0.000000            0.210496            0.130467
# 3               0.642226            0.132886            0.000000
# 4               0.099058            0.152003            0.073357
# ...                  ...                 ...                 ...
# 4825            0.031995            0.066882            0.139222
# 4826            0.255964            0.131357            0.000000
# 4827            0.187352            0.142930            0.000000
# 4828            0.644357            0.085861            0.631304
# 4829            0.003272            0.000000            0.010312
#
#       nd_mean_2021-07-05  nd_mean_2021-08-13  nd_mean_2021-08-27  \
# 0               0.026784            0.126832            0.614770
# 1               0.111148            0.174914            0.179612
# 2               0.155225            0.090607            0.054127
# 3               0.570928            0.073492            0.378900
# 4               0.147842            0.157676            0.012048
# ...                  ...                 ...                 ...
# 4825            0.009041            0.042483            0.022464
# 4826            0.187236            0.055721            0.044182
# 4827            0.047572            0.007225            0.145505
# 4828            0.694524            0.031836            0.453151
# 4829            0.227649            0.000000            0.096585
#
#       nd_mean_2021-05-08  nd_mean_2021-05-24
# 0               0.008857            0.081498
# 1               0.113071            0.046997
# 2               0.007437            0.219614
# 3               0.327677            0.586523
# 4               0.054223            0.017539
# ...                  ...                 ...
# 4825            0.017705            0.148440
# 4826            0.048316            0.041440
# 4827            0.051215            0.079730
# 4828            0.000000            0.006495
# 4829            0.000000            0.011459
#
# [4830 rows x 70 columns]

# %%
#!c1.32
from sklearn.model_selection import cross_validate

# %%
#!c1.32
X_ts_train, X_ts_val, y_ts_train, y_ts_val = train_test_split(X_ts, y_ts, train_size=0.75, random_state=42)

# %%
#!c1.32
c22 = Catch22Classifier(
    estimator=RandomForestClassifier(n_estimators=100, max_depth=40, random_state=42),
    outlier_norm=True,
)
c22.fit(X_ts_train.to_numpy(), y_ts_train)
# Out:
# Catch22Classifier(estimator=RandomForestClassifier(bootstrap=True,
#                                                    ccp_alpha=0.0,
#                                                    class_weight=None,
#                                                    criterion='gini',
#                                                    max_depth=40,
#                                                    max_features='auto',
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=1,
#                                                    min_samples_split=2,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=100,
#                                                    n_jobs=None, oob_score=False,
#                                                    random_state=42, verbose=0,
#                                                    warm_start=False),
#                   n_jobs=1, outlier_norm=True, random_state=None,
#                   replace_nans=True)

# %%
#!c1.32
recall_score(y_ts_val, c22.predict(X_ts_val.to_numpy()), average="macro", zero_division=0)
# Out:
# 0.697730047799496

# %% [markdown]
# # 5. Combinations

# %%
#!c1.32
classifires = {
    "rfc": gs34.best_estimator_,
    "cbc": CatBoostClassifier(iterations=200, depth=5, verbose=False,
                   loss_function="MultiClass", random_seed=42),
    "lgbm": LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
                importance_type='split', learning_rate=0.5, max_depth=8,
                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
                n_estimators=200, n_jobs=-1, num_leaves=20, objective=None,
                random_state=42, reg_alpha=0.0, reg_lambda=0, silent=True,
                subsample=1.0, subsample_for_bin=200000, subsample_freq=0),
    "xgb": XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
               colsample_bynode=1, colsample_bytree=1, gamma=0,
               grow_policy='depthwise', learning_rate=0.3, max_delta_step=0,
               max_depth=4, min_child_weight=1, missing=None, n_estimators=100,
               n_jobs=1, nthread=None, objective='multi:softprob',
               random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
               seed=None, silent=None, subsample=1, verbosity=1)
}

# %%
#!c1.32
X_tr, X_val, y_tr, y_val = train_test_split(transformer.transform(X), y, train_size=0.75, random_state=42)

# %%
#!c1.32
X_transformed = transformer.transform(X)
preds = {}
for name, clf in classifires.items():
    clf.fit(X_tr, y_tr)
    pred = clf.predict(X_val)
    preds[name] = pred

# %%
#!c1.32
recall_score(y_val, preds["cbc"], average="macro", zero_division=0)
# Out:
# 0.9564919187192731

# %%
#!c1.32
preds["rfc"]
# Out:
# array([0, 3, 3, ..., 5, 5, 2])

# %%
#!c1.32
preds["cbc"] = preds["cbc"].flatten()

# %%
#!c1.32
preds_df = pd.DataFrame(preds)

# %%
#!c1.32
preds_df["true"] = y_val.values
# Out:
#       rfc  cbc  lgbm  xgb  true
# 0       0    0     0    0     0
# 1       3    3     3    3     3
# 2       3    3     3    3     3
# 3       1    1     1    1     1
# 4       1    1     1    1     1
# ...   ...  ...   ...  ...   ...
# 1203    3    3     3    3     3
# 1204    0    0     0    0     0
# 1205    5    5     5    5     5
# 1206    5    5     5    5     5
# 1207    2    2     2    2     2
#
# [1208 rows x 5 columns]

# %%
#!c1.32
recall_score(y_val, preds_df.iloc[:, :-1].mode(axis=1)[0], average="macro", zero_division=0)
# Out:
# 0.9656240040872005

# %%
#!c1.32

# %%
#!c1.32
gs_preds_params = {
    "learning_rate": [0.1, 1],
    "max_depth": [4, 5, 6, 7],
    "num_leaves": [10, 20, 30]
}

gs_preds = GridSearchCV(LGBMClassifier(n_estimators=30, random_state=42),
                        gs_preds_params, scoring=recall_scorer, cv=5)
gs_preds.fit(preds_df.iloc[:, :-1], preds_df["true"])
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=LGBMClassifier(boosting_type='gbdt', class_weight=None,
#                                       colsample_bytree=1.0,
#                                       importance_type='split',
#                                       learning_rate=0.1, max_depth=-1,
#                                       min_child_samples=20,
#                                       min_child_weight=0.001,
#                                       min_split_gain=0.0, n_estimators=30,
#                                       n_jobs=-1, num_leaves=31, objective=None,
#                                       random_state=42, reg_alpha=0.0,
#                                       reg_lambda=0.0, silent=True,
#                                       subsample=1.0, subsample_for_bin=200000,
#                                       subsample_freq=0),
#              iid='deprecated', n_jobs=None,
#              param_grid={'learning_rate': [0.1, 1], 'max_depth': [4, 5, 6, 7],
#                          'num_leaves': [10, 20, 30]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=make_scorer(recall_score, average=macro, zero_division=0),
#              verbose=0)

# %%
#!c1.32
gs_preds.best_score_
# Out:
# 0.9679268181870512

# %%
#!c1.32
transformer2 = Pipeline([
    ("geo", GeoTransformer()),
    ("count_missing", MissingTSSummator()),
    #("stats", DescStatFeatureGenerator())
])

# %%
#!c1.32
gs35_params = {
    "n_estimators": range(70, 100, 3),
    "criterion": ["gini"], #, "entropy"],
    "max_depth": range(20, 61, 3),
    "min_samples_split": range(5, 41, 5)
}

gs35 = GridSearchCV(RandomForestClassifier(random_state=42), gs35_params,
                    scoring=recall_scorer, cv=3, verbose=1, n_jobs=32)
gs35.fit(transformer2.fit_transform(X), y)
# Out:
# Fitting 3 folds for each of 1120 candidates, totalling 3360 fits
# GridSearchCV(cv=3, estimator=RandomForestClassifier(random_state=42), n_jobs=32,
#              param_grid={'criterion': ['gini'], 'max_depth': range(20, 61, 3),
#                          'min_samples_split': range(5, 41, 5),
#                          'n_estimators': range(70, 100, 3)},
#              scoring=make_scorer(recall_score, average=macro, zero_division=0),
#              verbose=1)

# %%
#!c1.32
gs35.best_score_, gs35.best_estimator_
# Out:
# (0.9671030514967781,
#  RandomForestClassifier(max_depth=29, min_samples_split=5, n_estimators=70,
#                         random_state=42))

# %%
#!c1.32
gs36_params = {
    "num_leaves": range(10, 31, 10),
    "max_depth": range(4, 11),
    "learning_rate": [0.001, 0.01, 0.1, 0.2, 0.5, 0.7, 1],
    "reg_lambda": [0, 1, 10],
    "n_estimators": [10, 25, 50, 100, 200]
}

gs36 = GridSearchCV(LGBMClassifier(boosting_type="dart", random_state=42),
                    gs36_params,
                    scoring=recall_scorer, cv=3, verbose=1, n_jobs=32)
gs36.fit(transformer2.fit_transform(X), y)
# Out:
# Fitting 3 folds for each of 2205 candidates, totalling 6615 fits
# GridSearchCV(cv=3,
#              estimator=LGBMClassifier(boosting_type='dart', random_state=42),
#              n_jobs=32,
#              param_grid={'learning_rate': [0.001, 0.01, 0.1, 0.2, 0.5, 0.7, 1],
#                          'max_depth': range(4, 11),
#                          'n_estimators': [10, 25, 50, 100, 200],
#                          'num_leaves': range(10, 31, 10),
#                          'reg_lambda': [0, 1, 10]},
#              scoring=make_scorer(recall_score, average=macro, zero_division=0),
#              verbose=1)

# %%
#!c1.32
gs36.best_score_, gs36.best_estimator_
# Out:
# (0.9726520805412916,
#  LGBMClassifier(boosting_type='dart', learning_rate=0.7, max_depth=9,
#                 n_estimators=200, num_leaves=20, random_state=42, reg_lambda=0))

# %%
#!c1.32
save_sumbission(test, transformer2, gs36.best_estimator_, '36')

# %% [markdown]
# # 6. With `catch22` features

# %%
#!c1.32
from sktime.transformations.panel.catch22 import Catch22

# %%
#!c1.32
rows = []
for i, row in df.iterrows():
    row_t = Catch22().fit_transform(row[row.index.str.contains("nd")].astype("float32").to_numpy())
    rows.append(row_t)
catch22_df = pd.DataFrame(rows)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-0e56ae286d0a> in <module>
#       3     row_t = Catch22().fit_transform(row[row.index.str.contains("nd")].astype("float32").to_numpy())
#       4     rows.append(row_t)
# ----> 5 catch22_df = pd.DataFrame(rows)
#       6 #
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     758                     )
#     759                 else:
# --> 760                     mgr = ndarray_to_mgr(
#     761                         data,
#     762                         index,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     327         # by definition an array here
#     328         # the dtypes will be coerced to a single dtype
# --> 329         values = _prep_ndarraylike(values, copy=copy_on_sanitize)
#     330
#     331     if dtype is not None and not is_dtype_equal(values.dtype, dtype):
#
# ~/.local/lib/python3.8/site-packages/pandas/core/internals/construction.py in _prep_ndarraylike(values, copy)
#     581         values = values.reshape((values.shape[0], 1))
#     582     elif values.ndim != 2:
# --> 583         raise ValueError(f"Must pass 2-d input. shape={values.shape}")
#     584
#     585     return values
#
# ValueError: Must pass 2-d input. shape=(4830, 1, 22)

# %%
#!c1.32
catch22_df = pd.concat(rows, axis=0)
catch22_df.head()
# Out:
#          0         1     2         3    4    5    6         7         8   \
# 0  0.075486  0.037743   6.0 -0.200000  0.0  1.0  2.0  0.021755  1.079922
# 0  0.070904  0.035452   9.0 -0.285714  0.0  2.0  2.0  0.032605  0.589049
# 0  0.074117  0.037059  14.0 -0.371429  0.0  7.0  1.0  0.036986  0.196350
# 0  0.075328  0.037664   9.0 -0.264286  0.0  1.0  4.0  0.026207  0.785398
# 0  0.083369  0.041685   7.0 -0.214286  0.0  4.0  4.0  0.046433  0.245437
#
#          9   ...   12        13   14        15        16        17        18  \
# 0  0.251422  ...  1.0  0.739130  4.0  2.153809  0.090909  0.747868  0.758621
# 0  0.254183  ...  1.0  0.797101  4.0  2.081770  0.166667  0.891584  0.758621
# 0  0.200494  ...  2.0  0.811594  4.0  1.993455  0.076923  0.724670  0.586207
# 0  0.256016  ...  3.0  0.768116  3.0  2.134880  0.125000  0.771501  0.793103
# 0  0.214467  ...  3.0  0.768116  5.0  2.062417  0.066667  0.842103  0.758621
#
#          19        20    21
# 0  0.655172  0.055556   4.0
# 0  0.793103  0.019284   9.0
# 0  0.689655  0.040000  19.0
# 0  0.793103  0.015625   0.0
# 0  0.689655  0.062500  21.0
#
# [5 rows x 22 columns]

# %%
#!c1.32
catch22_df.reset_index(drop=True)
# Out:
#             0         1     2         3    4    5     6         7         8   \
# 0     0.075486  0.037743   6.0 -0.200000  0.0  1.0   2.0  0.021755  1.079922
# 1     0.070904  0.035452   9.0 -0.285714  0.0  2.0   2.0  0.032605  0.589049
# 2     0.074117  0.037059  14.0 -0.371429  0.0  7.0   1.0  0.036986  0.196350
# 3     0.075328  0.037664   9.0 -0.264286  0.0  1.0   4.0  0.026207  0.785398
# 4     0.083369  0.041685   7.0 -0.214286  0.0  4.0   4.0  0.046433  0.245437
# ...        ...       ...   ...       ...  ...  ...   ...       ...       ...
# 4825  0.080159  0.040080  15.0 -0.214286  0.0  7.0   4.0  0.049762  0.196350
# 4826  0.084526  0.042263  20.0 -0.228571  0.0  6.0   8.0  0.078439  0.147262
# 4827  0.084462  0.042231  14.0 -0.250000  0.0  4.0  18.0  0.057400  0.245437
# 4828  0.076714  0.038357  12.0 -0.257143  0.0  1.0   1.0  0.031052  0.687223
# 4829  0.083241  0.041620  16.0 -0.257143  0.0  8.0   1.0  0.065207  0.147262
#
#             9   ...    12        13   14        15        16        17  \
# 0     0.251422  ...   1.0  0.739130  4.0  2.153809  0.090909  0.747868
# 1     0.254183  ...   1.0  0.797101  4.0  2.081770  0.166667  0.891584
# 2     0.200494  ...   2.0  0.811594  4.0  1.993455  0.076923  0.724670
# 3     0.256016  ...   3.0  0.768116  3.0  2.134880  0.125000  0.771501
# 4     0.214467  ...   3.0  0.768116  5.0  2.062417  0.066667  0.842103
# ...        ...  ...   ...       ...  ...       ...       ...       ...
# 4825  0.215046  ...   3.0  0.724638  4.0  2.030616  0.076923  0.980926
# 4826  0.206271  ...   7.0  0.521739  5.0  1.951321  0.062500  0.866993
# 4827  0.250103  ...  13.0  0.797101  5.0  2.091965  0.066667  0.821984
# 4828  0.247107  ...   7.0  0.869565  4.0  2.150615  0.066667  0.763008
# 4829  0.205123  ...  10.0  0.681159  5.0  2.051803  0.071429  0.995493
#
#             18        19        20    21
# 0     0.758621  0.655172  0.055556   4.0
# 1     0.758621  0.793103  0.019284   9.0
# 2     0.586207  0.689655  0.040000  19.0
# 3     0.793103  0.793103  0.015625   0.0
# 4     0.758621  0.689655  0.062500  21.0
# ...        ...       ...       ...   ...
# 4825  0.689655  0.689655  0.040000  21.0
# 4826  0.758621  0.758621  0.062500   0.0
# 4827  0.586207  0.689655  0.062500  20.0
# 4828  0.758621  0.655172  0.062500   8.0
# 4829  0.758621  0.689655  0.125000  20.0
#
# [4830 rows x 22 columns]

# %%
#!c1.32
from sktime.transformations.panel.catch22 import Catch22

class Catch22FeatureGenerator(BaseEstimator, TransformerMixin):
    def __init__(self, col_prefix="nd_mean_"):
        self.col_prefix = col_prefix
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        result = X.copy()
        features = []
        
        for _, row in result.iterrows():
            series = row[row.index.str.contains(self.col_prefix)].astype("float32").to_numpy()
            feature_row = Catch22().fit_transform(series)
            features.append(feature_row)
        catch22_df = pd.concat(features)
        catch22_df.rename(columns=lambda x: f"catch22_f{x}", inplace=True)
        catch22_df.reset_index(drop=True, inplace=True)
        
        assert catch22_df.shape[0] == result.shape[0]
        result = pd.concat([result, catch22_df], axis=1)       
        
        return result

# %%
#!c1.32
Catch22FeatureGenerator().fit_transform(df)
# Out:
#         id  area  nd_mean_2021-04-16  nd_mean_2021-04-19  nd_mean_2021-04-22  \
# 0     3536    20            0.072846            0.261778            0.062981
# 1     3739    45            0.332928            0.287182            0.097138
# 2     1294    28            0.013679            0.007055            0.120804
# 3     2859    19            0.105976            0.052500            0.001917
# 4     3685    33            0.130885            0.063492            0.024416
# ...    ...   ...                 ...                 ...                 ...
# 4825  3772    74            0.028770            0.038282            0.255329
# 4826  5191   109            0.035939            0.030722            0.033869
# 4827  5226    58            0.191255            0.063581            0.140111
# 4828  5390    14            0.291399            0.221428            0.007247
# 4829   860    75            0.226925            0.043076            0.058611
#
#       nd_mean_2021-04-26  nd_mean_2021-04-28  nd_mean_2021-05-02  \
# 0               0.104442            0.021096            0.052202
# 1               0.152467            0.075484            0.000000
# 2               0.037839            0.259125            0.000000
# 3               0.011531            0.042316            0.000000
# 4               0.000000            0.150671            0.046717
# ...                  ...                 ...                 ...
# 4825            0.148166            0.225421            0.479483
# 4826            0.029646            0.318387            0.247905
# 4827            0.323984            0.000000            0.005056
# 4828            0.055074            0.057781            0.187749
# 4829            0.440539            0.120169            0.138846
#
#       nd_mean_2021-05-04  nd_mean_2021-05-07  ...  catch22_f12  catch22_f13  \
# 0               0.158723            0.000000  ...          1.0     0.739130
# 1               0.140326            0.163340  ...          1.0     0.797101
# 2               0.037446            0.506516  ...          2.0     0.811594
# 3               0.000000            0.043604  ...          3.0     0.768116
# 4               0.254284            0.101479  ...          3.0     0.768116
# ...                  ...                 ...  ...          ...          ...
# 4825            0.071684            0.016856  ...          3.0     0.724638
# 4826            0.265180            0.286298  ...          7.0     0.521739
# 4827            0.092693            0.399439  ...         13.0     0.797101
# 4828            0.112403            0.183555  ...          7.0     0.869565
# 4829            0.020173            0.117669  ...         10.0     0.681159
#
#       catch22_f14  catch22_f15  catch22_f16  catch22_f17  catch22_f18  \
# 0             4.0     2.153809     0.090909     0.747868     0.758621
# 1             4.0     2.081770     0.166667     0.891584     0.758621
# 2             4.0     1.993455     0.076923     0.724670     0.586207
# 3             3.0     2.134880     0.125000     0.771501     0.793103
# 4             5.0     2.062417     0.066667     0.842103     0.758621
# ...           ...          ...          ...          ...          ...
# 4825          4.0     2.030616     0.076923     0.980926     0.689655
# 4826          5.0     1.951321     0.062500     0.866993     0.758621
# 4827          5.0     2.091965     0.066667     0.821984     0.586207
# 4828          4.0     2.150615     0.066667     0.763008     0.758621
# 4829          5.0     2.051803     0.071429     0.995493     0.758621
#
#       catch22_f19  catch22_f20  catch22_f21
# 0        0.655172     0.055556          4.0
# 1        0.793103     0.019284          9.0
# 2        0.689655     0.040000         19.0
# 3        0.793103     0.015625          0.0
# 4        0.689655     0.062500         21.0
# ...           ...          ...          ...
# 4825     0.689655     0.040000         21.0
# 4826     0.758621     0.062500          0.0
# 4827     0.689655     0.062500         20.0
# 4828     0.655172     0.062500          8.0
# 4829     0.689655     0.125000         20.0
#
# [4830 rows x 96 columns]

# %%
#!c1.32
X = df.drop(columns=["id", "crop"])
y = df["crop"]

# %%
#!c1.32
transformer3 = Pipeline([
    ("geo", GeoTransformer(edges=True)),
    ("count_missing", MissingTSSummator()),
    ("catch22", Catch22FeatureGenerator()),
    ("stats", DescStatFeatureGenerator())
])

# %%
#!c1.32
gs61_params = {
    "n_estimators": range(70, 100, 3),
    "criterion": ["gini"],
    "max_depth": range(20, 61, 3),
    "min_samples_split": range(5, 41, 5)
}

gs61 = GridSearchCV(RandomForestClassifier(random_state=42), gs61_params,
                    scoring=recall_scorer, cv=3, verbose=1, n_jobs=32)
gs61.fit(transformer3.fit_transform(X), y)
# Out:
# Fitting 3 folds for each of 1120 candidates, totalling 3360 fits
# GridSearchCV(cv=3, estimator=RandomForestClassifier(random_state=42), n_jobs=32,
#              param_grid={'criterion': ['gini'], 'max_depth': range(20, 61, 3),
#                          'min_samples_split': range(5, 41, 5),
#                          'n_estimators': range(70, 100, 3)},
#              scoring=make_scorer(recall_score, average=macro, zero_division=0),
#              verbose=1)

# %%
#!c1.32
gs61.best_score_, gs61.best_estimator_
# Out:
# (0.9654941778120004,
#  RandomForestClassifier(max_depth=23, min_samples_split=5, n_estimators=97,
#                         random_state=42))

# %%
#!c1.32
gs36_params = {
    "num_leaves": range(10, 31, 10),
    "max_depth": range(4, 11),
    "learning_rate": [0.001, 0.01, 0.1, 0.2, 0.5, 0.7, 1],
    "reg_lambda": [0, 1, 10],
    "n_estimators": [10, 25, 50, 100, 200, 500]
}

gs36 = GridSearchCV(LGBMClassifier(boosting_type="dart", random_state=42),
                    gs36_params,
                    scoring=recall_scorer, cv=3, verbose=1, n_jobs=32)
gs36.fit(transformer3.fit_transform(X), y)
# Out:
# Fitting 3 folds for each of 2646 candidates, totalling 7938 fits
# GridSearchCV(cv=3,
#              estimator=LGBMClassifier(boosting_type='dart', random_state=42),
#              n_jobs=32,
#              param_grid={'learning_rate': [0.001, 0.01, 0.1, 0.2, 0.5, 0.7, 1],
#                          'max_depth': range(4, 11),
#                          'n_estimators': [10, 25, 50, 100, 200, 500],
#                          'num_leaves': range(10, 31, 10),
#                          'reg_lambda': [0, 1, 10]},
#              scoring=make_scorer(recall_score, average=macro, zero_division=0),
#              verbose=1)

# %%
#!c1.32
gs62.best_score_, gs62.best_estimator_
# Out:
# (0.9733999725034846,
#  LGBMClassifier(boosting_type='dart', learning_rate=0.5, max_depth=7,
#                 n_estimators=500, num_leaves=20, random_state=42, reg_lambda=0))

# %%
#!c1.32
gs62_2_params = {
    "random_state": range(10, 31),
}

gs62_2 = GridSearchCV(LGBMClassifier(boosting_type="dart", n_estimators=500,
                                     learning_rate=0.5, max_depth=7, num_leaves=20, reg_lambda=0),
                    gs62_2_params,
                    scoring=recall_scorer, cv=3, verbose=1, n_jobs=32)
gs62_2.fit(transformer3.fit_transform(X), y)
# Out:
# Fitting 3 folds for each of 21 candidates, totalling 63 fits
# GridSearchCV(cv=3,
#              estimator=LGBMClassifier(boosting_type='dart', learning_rate=0.5,
#                                       max_depth=7, n_estimators=500,
#                                       num_leaves=20, reg_lambda=0),
#              n_jobs=32, param_grid={'random_state': range(10, 31)},
#              scoring=make_scorer(recall_score, average=macro, zero_division=0),
#              verbose=1)

# %%
#!c1.32
gs62_2.best_score_, gs62_2.best_estimator_
# Out:
# (0.9731838325146175,
#  LGBMClassifier(boosting_type='dart', learning_rate=0.5, max_depth=7,
#                 n_estimators=500, num_leaves=20, random_state=10, reg_lambda=0))

# %%
#!c1.32
save_sumbission(test, transformer3, gs62_2.best_estimator_, "62_3")

# %%
#!c1.32
gs37_params = {
    "num_leaves": range(15, 26, 5),
    "max_depth": range(6, 7),
    "learning_rate": [0.25, 0.5, 0.75],
    "reg_lambda": [0],
    "n_estimators": [500]
}

gs37 = GridSearchCV(LGBMClassifier(boosting_type="dart", random_state=42),
                    gs37_params,
                    scoring=recall_scorer, cv=3, verbose=1, n_jobs=32)
gs37.fit(transformer3.fit_transform(X), y)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# GridSearchCV(cv=3,
#              estimator=LGBMClassifier(boosting_type='dart', random_state=42),
#              n_jobs=32,
#              param_grid={'learning_rate': [0.25, 0.5, 0.75],
#                          'max_depth': range(6, 7), 'n_estimators': [500],
#                          'num_leaves': range(15, 26, 5), 'reg_lambda': [0]},
#              scoring=make_scorer(recall_score, average=macro, zero_division=0),
#              verbose=1)

# %%
#!c1.32
gs37.best_score_, gs37.best_estimator_
# Out:
# (0.9715540202322158,
#  LGBMClassifier(boosting_type='dart', learning_rate=0.25, max_depth=6,
#                 n_estimators=500, num_leaves=15, random_state=42, reg_lambda=0))

# %%
#!c1.32
save_sumbission(test, transformer3, gs37.best_estimator_, "37")

# %%
#!c1.32
